# %% [markdown]
# # Conditional Generation with Transformers

# %%
import json
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchinfo import summary

# %%
data = pd.read_csv('../Data/data_tokenized_pitch_class.csv')
data["chords"] = data["chords"].apply(lambda x: torch.tensor(json.loads(x)))
data.head()
# Out:
#                                                  url  \
# 0  https://tabs.ultimate-guitar.com/tab/jeff-buck...
# 1  https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 2  https://tabs.ultimate-guitar.com/tab/elvis-pre...
# 3  https://tabs.ultimate-guitar.com/tab/eagles/ho...
# 4  https://tabs.ultimate-guitar.com/tab/radiohead...
#
#                        title         artist  decade  \
# 0                 Hallelujah   Jeff Buckley    1990
# 1                    Perfect     Ed Sheeran    2010
# 2  Cant Help Falling In Love  Elvis Presley    1960
# 3           Hotel California         Eagles    1970
# 4                      Creep      Radiohead    1990
#
#                          genre  ratings  stars  \
# 0                    Rock|Folk  51639.0    5.0
# 1                          Pop  44194.0    5.0
# 2  Soundtrack|R&B, Funk & Soul  30059.0    5.0
# 3                         Rock  28670.0    5.0
# 4                         Rock  28606.0    5.0
#
#                                               chords
# 0  [tensor(648), tensor(640), tensor(648), tensor...
# 1  [tensor(155), tensor(31), tensor(648), tensor(...
# 2  [tensor(648), tensor(155), tensor(640), tensor...
# 3  [tensor(166), tensor(403), tensor(380), tensor...
# 4  [tensor(155), tensor(78), tensor(648), tensor(...

# %%
augmentation_map = torch.tensor(np.load('../Data/augmentation_map.npy', allow_pickle=True))

with open("../Data/token_to_chord.json", "r") as f:
    token_to_chord = json.load(f)

# %%
VOCAB_SIZE = len(token_to_chord) + 2
VOCAB_SIZE
# Out:
# 975

# %% [markdown]
# ## Dataset

# %%
class ChordDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.all_genres = data["genre"].apply(lambda x: x.split("|")).explode().unique()
        self.all_decades = data["decade"].unique()
        self.genre_to_idx = {genre: i for i, genre in enumerate(self.all_genres)}
        self.decade_to_idx = {decade: i for i, decade in enumerate(self.all_decades)}

        self.style_dim = len(self.all_genres) + len(self.all_decades)
    
    def augment(self, chords):
        """Change the root note of the chords by a random amount"""
        move_by = torch.randint(0, 12, [1]).item()
        return augmentation_map[chords, move_by]
        
    def pad(self, chords):
        """Pad the input 2D tensor [n] into shape [256] with zeros"""
        out = torch.zeros((256))
        out[0] = VOCAB_SIZE - 2 # Start of sequence token
        out[1:len(chords) + 1] = chords
        out[len(chords) + 1] = VOCAB_SIZE - 1 # End of sequence token
        return out

    def multi_hot(self, genres, decade):
        """Convert a list of genres and a decade into a multi-hot vector"""
        genre_style = torch.zeros((len(self.all_genres)))
        genre_style[[self.genre_to_idx[genre] for genre in genres]] = 1
        genre_style /= genre_style.sum() # Normalize as there can be multiple genres
        
        decade_style = torch.zeros((len(self.all_decades)))
        decade_style[self.decade_to_idx[decade]] = 1
        
        return torch.cat([genre_style, decade_style])
        
    def __getitem__(self, index):
        row = self.data.iloc[index]
        x = self.augment(row["chords"])
        x = self.pad(x).long()
        
        genres = self.multi_hot(row["genre"].split("|"), row["decade"])
        
        return x, genres

    def __len__(self):
        return len(self.data)

# %%
torch.manual_seed(42)

dataset = ChordDataset(data)
train_size = np.rint(len(dataset) * 0.8).astype(int)
train_data, test_data = random_split(dataset, [train_size, len(dataset) - train_size])

# %%
# Define the dataloaders
train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
test_loader = DataLoader(test_data, batch_size=128, shuffle=True)

# %% [markdown]
# ## Model

# %%
class AdaptiveLayerNorm(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.norm = nn.LayerNorm(d_model)
        self.gain = nn.Linear(d_model, d_model)
        self.bias = nn.Linear(d_model, d_model)            
        
    def forward(self, x, style):
        gain = self.gain(F.relu(style)).unsqueeze(1).repeat(1, x.shape[1], 1)
        bias = self.bias(F.relu(style)).unsqueeze(1).repeat(1, x.shape[1], 1)
        return (1 + gain) * self.norm(x) + bias
                 

class TransformerBlock(nn.Module):
    def __init__(self, d_model, n_heads):
        super().__init__()
        self.layer_norm1 = AdaptiveLayerNorm(d_model)
        self.multi_head_attention = nn.MultiheadAttention(
            embed_dim=d_model, num_heads=n_heads, batch_first=True
        )
        self.dropout1 = nn.Dropout(0.1)
        self.layer_norm2 = AdaptiveLayerNorm(d_model)
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, d_model * 4), nn.ReLU(), nn.Linear(d_model * 4, d_model)
        )
        self.dropout2 = nn.Dropout(0.1)

    def forward(self, x, style, mask=None):
        # Multi-head attention
        att_input = self.layer_norm1(x, style)
        att_output = self.multi_head_attention(att_input, att_input, att_input, attn_mask=mask, need_weights=False)[0]
        x = x + self.dropout1(att_output)

        # Feed forward
        ff_input = self.layer_norm2(x, style)
        ff_output = self.feed_forward(ff_input)
        x = x + self.dropout2(ff_output)
        
        return x 


class ConditionalTransformer(nn.Module):
    def __init__(self, d_model, n_heads, n_layers, input_len):
        super().__init__()
        self.style_map = nn.Linear(dataset.style_dim, d_model)
        self.embedding = nn.Embedding(VOCAB_SIZE, d_model)
        self.transformer_blocks = nn.ModuleList([TransformerBlock(d_model, n_heads) for _ in range(n_layers)])
        self.output = nn.Linear(d_model, VOCAB_SIZE)

        # Positional encoding
        self.register_buffer('pe', torch.zeros(input_len, d_model))
        self.pe = torch.zeros(input_len, d_model)
        pos = torch.arange(0, input_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model)
        )
        self.pe[:, 0::2] = torch.sin(pos * div_term)
        self.pe[:, 1::2] = torch.cos(pos * div_term)
        

    def generate_square_subsequent_mask(self, size):
        """Generate a mask to avoid using future tokens."""
        mask = (torch.triu(torch.ones(size, size)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask


    def forward(self, x, style):
        x = self.embedding(x)
        style = self.style_map(style)
        x = x + self.pe
        
        # Generate mask
        mask = self.generate_square_subsequent_mask(x.size(1)).to(x.device)
        
        # Passing through all transformer blocks
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x, style, mask)
        x = self.output(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# The hyperparameters are the same as for the basic Transformer architecture:
# * CondTransformerS: `d_model` = 64, `n_heads` = 8, `n_layers` = 6 (527k total params)
# * CondTransformerM: `d_model` = 80, `n_heads` = 10, `n_layers` = 12 (1.404M total params)
# * CondTransformerL: `d_model` = 96, `n_heads` = 12, `n_layers` = 24 (3.769M total params)

# %%
conditional_transformer = ConditionalTransformer(
    d_model=64,
    n_heads=8,
    n_layers=6,
    input_len=256
).to(device)
dummy_input = torch.zeros((1, 256), dtype=torch.long).to(device)
dummy_style = torch.zeros((1, dataset.style_dim)).to(device)
summary(conditional_transformer, input_data=(dummy_input, dummy_style))
# Out:
# d:\Programs\anaconda3\lib\site-packages\torch\nn\modules\activation.py:1144: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\attention.cpp:152.)
#   return torch._native_multi_head_attention(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ConditionalTransformer                   [1, 256, 975]             --
# ├─Embedding: 1-1                         [1, 256, 64]              62,400
# ├─Linear: 1-2                            [1, 64]                   1,856
# ├─ModuleList: 1-3                        --                        --
# │    └─TransformerBlock: 2-1             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-1       [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-2      [1, 256, 64]              16,640
# │    │    └─Dropout: 3-3                 [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-4       [1, 256, 64]              8,448
# │    │    └─Sequential: 3-5              [1, 256, 64]              33,088
# │    │    └─Dropout: 3-6                 [1, 256, 64]              --
# │    └─TransformerBlock: 2-2             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-7       [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-8      [1, 256, 64]              16,640
# │    │    └─Dropout: 3-9                 [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-10      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-11             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-12                [1, 256, 64]              --
# │    └─TransformerBlock: 2-3             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-13      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-14     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-15                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-16      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-17             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-18                [1, 256, 64]              --
# │    └─TransformerBlock: 2-4             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-19      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-20     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-21                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-22      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-23             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-24                [1, 256, 64]              --
# │    └─TransformerBlock: 2-5             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-25      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-26     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-27                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-28      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-29             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-30                [1, 256, 64]              --
# │    └─TransformerBlock: 2-6             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-31      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-32     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-33                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-34      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-35             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-36                [1, 256, 64]              --
# ├─Linear: 1-4                            [1, 256, 975]             63,375
# ==========================================================================================
# Total params: 527,375
# Trainable params: 527,375
# Non-trainable params: 0
# Total mult-adds (M): 0.43
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 7.65
# Params size (MB): 1.71
# Estimated Total Size (MB): 9.36
# ==========================================================================================

# %% [markdown]
# ## Trainer

# %%
class Trainer():
    def __init__(self, epochs, train_loader, test_loader, model, optimizer, device, lr_scheduler):
        self.epochs = epochs
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.model = model
        self.optimizer = optimizer
        self.device = device
        self.print_every = 16
        self.lr_scheduler = lr_scheduler
        
        self.step_data = {"train_losses": [], "test_losses": [],  "train_accuracies": [], "test_accuracies": []}
        self.epoch_data = {"train_losses": [], "test_losses": [], "train_accuracies": [], "test_accuracies": []}
    

    def loss_mask(self, y_pred, x):
        """Get the mask for the loss function"""
        eos_index = torch.argmax((x == VOCAB_SIZE - 1).float(), dim=1)
        range_tensor = torch.arange(y_pred.shape[1]).unsqueeze(0).expand(y_pred.shape[0], -1).to(self.device)
        mask = range_tensor <= eos_index.unsqueeze(1)
        return mask
    
    def masked_accuracy(self, y_pred, x):
        """Calculate the accuracy of the model for elements of the sequence"""
        y_pred, x = y_pred[:, :-1], x[:, 1:]
        eos_index = torch.argmax((x == VOCAB_SIZE - 1).float(), dim=1)
        range_tensor = torch.arange(y_pred.shape[1]).unsqueeze(0).expand(y_pred.shape[0], -1).to(self.device)
        # EOS is not included in the accuracy calculation
        mask = range_tensor < eos_index.unsqueeze(1)
        valid_elements = torch.sum(mask.float())

        same = torch.argmax(y_pred, dim=2) == x
            
        return torch.sum(same.float() * mask.float()) / valid_elements
    
    def masked_cross_entropy(self, logits, target, mask):
        """
        logits: Predictions from the model, of shape (batch_size, sequence_length, num_classes)
        target: Ground truth labels, of shape (batch_size, sequence_length)
        mask: Binary mask indicating the non-padded parts, of shape (batch_size, sequence_length)
        """
        # Flatten all the dimensions except for the classes dimension
        logits_flat = logits.reshape(-1, logits.size(-1))
        target_flat = target.reshape(-1)
        mask_flat = mask.reshape(-1).float()
        
        # Compute the CrossEntropyLoss
        loss = nn.CrossEntropyLoss(reduction='none')(logits_flat, target_flat)
        
        # Apply the mask to the loss
        masked_loss = loss * mask_flat
        
        # Compute the mean loss over non-padded parts
        final_loss = masked_loss.sum() / mask_flat.sum()
        
        return final_loss

    
    def train_step(self):
        self.model.train()
        for i, (x, style) in enumerate(self.train_loader):
            x, style = x.to(self.device), style.to(self.device)
            y_pred = self.model(x, style)
            mask = self.loss_mask(y_pred, x)
            
            loss = self.masked_cross_entropy(y_pred[:, :-1], x[:, 1:], mask[:, :-1])
            self.step_data["train_losses"].append(loss.item())
            self.step_data["train_accuracies"].append(self.masked_accuracy(y_pred, x).item())

            if i % self.print_every == self.print_every - 1:
                print(f"Batch {i + 1}/{len(self.train_loader)}, Loss: {loss.item():.4f}, Accuracy: {self.step_data['train_accuracies'][-1]:.4f}")
                            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            
        self.epoch_data["train_losses"].append(np.array(self.step_data["train_losses"]).mean())
        self.epoch_data["train_accuracies"].append(np.array(self.step_data["train_accuracies"]).mean())
                   
        
    def eval_step(self):
        self.model.eval()
        for i, (x, style) in enumerate(self.train_loader):
            x, style = x.to(self.device), style.to(self.device)
            with torch.inference_mode():
                y_pred = self.model(x, style)

            mask = self.loss_mask(y_pred, x)            
            loss = self.masked_cross_entropy(y_pred[:, :-1], x[:, 1:], mask[:, :-1])
            self.step_data["test_losses"].append(loss.item())
            self.step_data["test_accuracies"].append(self.masked_accuracy(y_pred, x).item())
        
        self.epoch_data["test_losses"].append(np.array(self.step_data["test_losses"]).mean())
        self.epoch_data["test_accuracies"].append(np.array(self.step_data["test_accuracies"]).mean())
                    
        
        print(f"Test Loss: {loss.item():.4f},  Accuracy: {self.step_data['test_accuracies'][-1]:.4f}")

    def plot(self):
        fig, axes = plt.subplots(2, 1, figsize=(15, 15))
        axes[0].set_title("Loss")
        sns.lineplot(x=range(len(self.epoch_data["train_losses"])), y=self.epoch_data["train_losses"], label="Train Loss", ax=axes[0])
        sns.lineplot(x=range(len(self.epoch_data["test_losses"])), y=self.epoch_data["test_losses"], label="Test Loss", ax=axes[0])
        
        axes[1].set_title("Total Accuracy")
        sns.lineplot(x=range(len(self.epoch_data["train_accuracies"])), y=self.epoch_data["train_accuracies"], label="Train Accuracy", ax=axes[1])
        sns.lineplot(x=range(len(self.epoch_data["test_accuracies"])), y=self.epoch_data["test_accuracies"], label="Test Accuracy", ax=axes[1])
        
    
    def init_metrics(self):
        self.step_data = {"train_losses": [], "test_losses": [], "train_accuracies": [], "test_accuracies": []}

        
    def train(self):    
        for epoch in range(self.epochs):
            print(f"Epoch {epoch + 1}/{self.epochs}\n-------------------------------")
            self.init_metrics()
            self.train_step()
            self.eval_step()
            self.lr_scheduler.step()
            
        self.plot()

# %% [markdown]
# ## Training

# %%
optimizer = torch.optim.Adam(conditional_transformer.parameters(), lr=0.001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.3)
trainer = Trainer(
    epochs=50,
    train_loader=train_loader,
    test_loader=test_loader,
    model=conditional_transformer,
    optimizer=optimizer,
    device=device,
    lr_scheduler=lr_scheduler,
)

# %%
trainer.train()
# Out:
# Epoch 1/50
# -------------------------------
# Batch 16/139, Loss: 3.5205, Accuracy: 0.2632
# Batch 32/139, Loss: 2.8513, Accuracy: 0.3195
# Batch 48/139, Loss: 2.6690, Accuracy: 0.3491
# Batch 64/139, Loss: 2.6186, Accuracy: 0.3252
# Batch 80/139, Loss: 2.2653, Accuracy: 0.3868
# Batch 96/139, Loss: 2.2453, Accuracy: 0.3760
# Batch 112/139, Loss: 2.1553, Accuracy: 0.3880
# Batch 128/139, Loss: 2.1625, Accuracy: 0.3870
# Test Loss: 2.1943,  Accuracy: 0.3964
# Epoch 2/50
# -------------------------------
# Batch 16/139, Loss: 2.0374, Accuracy: 0.4144
# Batch 32/139, Loss: 2.0799, Accuracy: 0.4043
# Batch 48/139, Loss: 2.0045, Accuracy: 0.3854
# Batch 64/139, Loss: 2.0579, Accuracy: 0.3774
# Batch 80/139, Loss: 2.0394, Accuracy: 0.3945
# Batch 96/139, Loss: 1.9657, Accuracy: 0.4239
# Batch 112/139, Loss: 1.9309, Accuracy: 0.4127
# Batch 128/139, Loss: 1.9557, Accuracy: 0.4149
# Test Loss: 1.8715,  Accuracy: 0.4214
# Epoch 3/50
# -------------------------------
# Batch 16/139, Loss: 2.0300, Accuracy: 0.4078
# Batch 32/139, Loss: 2.0146, Accuracy: 0.3986
# Batch 48/139, Loss: 1.9440, Accuracy: 0.4256
# Batch 64/139, Loss: 1.9179, Accuracy: 0.4236
# Batch 80/139, Loss: 1.9258, Accuracy: 0.4147
# Batch 96/139, Loss: 2.0617, Accuracy: 0.4077
# Batch 112/139, Loss: 1.9126, Accuracy: 0.4020
# Batch 128/139, Loss: 1.9771, Accuracy: 0.4019
# Test Loss: 1.8445,  Accuracy: 0.4775
# Epoch 4/50
# -------------------------------
# Batch 16/139, Loss: 1.9047, Accuracy: 0.4009
# Batch 32/139, Loss: 1.9983, Accuracy: 0.3770
# Batch 48/139, Loss: 1.8711, Accuracy: 0.4193
# Batch 64/139, Loss: 2.0120, Accuracy: 0.3943
# Batch 80/139, Loss: 1.8982, Accuracy: 0.4192
# Batch 96/139, Loss: 2.0175, Accuracy: 0.4019
# Batch 112/139, Loss: 1.8842, Accuracy: 0.4297
# Batch 128/139, Loss: 1.8320, Accuracy: 0.4383
# Test Loss: 1.8154,  Accuracy: 0.4451
# Epoch 5/50
# -------------------------------
# Batch 16/139, Loss: 1.8395, Accuracy: 0.4269
# Batch 32/139, Loss: 1.8857, Accuracy: 0.4159
# Batch 48/139, Loss: 1.9954, Accuracy: 0.4057
# Batch 64/139, Loss: 1.8337, Accuracy: 0.4168
# Batch 80/139, Loss: 1.7574, Accuracy: 0.4587
# Batch 96/139, Loss: 1.8866, Accuracy: 0.4141
# Batch 112/139, Loss: 1.7908, Accuracy: 0.4387
# Batch 128/139, Loss: 1.9425, Accuracy: 0.4146
# Test Loss: 1.8096,  Accuracy: 0.4366
# Epoch 6/50
# -------------------------------
# Batch 16/139, Loss: 1.8731, Accuracy: 0.4355
# Batch 32/139, Loss: 1.7951, Accuracy: 0.4349
# Batch 48/139, Loss: 1.7798, Accuracy: 0.4426
# Batch 64/139, Loss: 1.8476, Accuracy: 0.4266
# Batch 80/139, Loss: 1.8774, Accuracy: 0.4304
# Batch 96/139, Loss: 1.6507, Accuracy: 0.4876
# Batch 112/139, Loss: 1.7230, Accuracy: 0.4556
# Batch 128/139, Loss: 1.8038, Accuracy: 0.4288
# Test Loss: 1.7152,  Accuracy: 0.4672
# Epoch 7/50
# -------------------------------
# Batch 16/139, Loss: 1.7302, Accuracy: 0.4733
# Batch 32/139, Loss: 1.7328, Accuracy: 0.4602
# Batch 48/139, Loss: 1.7127, Accuracy: 0.4703
# Batch 64/139, Loss: 1.6994, Accuracy: 0.4687
# Batch 80/139, Loss: 1.6554, Accuracy: 0.4847
# Batch 96/139, Loss: 1.7589, Accuracy: 0.4476
# Batch 112/139, Loss: 1.8179, Accuracy: 0.4512
# Batch 128/139, Loss: 1.7201, Accuracy: 0.4376
# Test Loss: 1.6771,  Accuracy: 0.4837
# Epoch 8/50
# -------------------------------
# Batch 16/139, Loss: 1.7848, Accuracy: 0.4588
# Batch 32/139, Loss: 1.6970, Accuracy: 0.4630
# Batch 48/139, Loss: 1.7853, Accuracy: 0.4471
# Batch 64/139, Loss: 1.8447, Accuracy: 0.4782
# Batch 80/139, Loss: 1.6879, Accuracy: 0.4962
# Batch 96/139, Loss: 1.6834, Accuracy: 0.5050
# Batch 112/139, Loss: 1.7340, Accuracy: 0.4799
# Batch 128/139, Loss: 1.7653, Accuracy: 0.4881
# Test Loss: 1.6246,  Accuracy: 0.5300
# Epoch 9/50
# -------------------------------
# Batch 16/139, Loss: 1.7000, Accuracy: 0.5254
# Batch 32/139, Loss: 1.4857, Accuracy: 0.5553
# Batch 48/139, Loss: 1.7007, Accuracy: 0.5188
# Batch 64/139, Loss: 1.6128, Accuracy: 0.5422
# Batch 80/139, Loss: 1.5963, Accuracy: 0.5331
# Batch 96/139, Loss: 1.7345, Accuracy: 0.5092
# Batch 112/139, Loss: 1.6911, Accuracy: 0.5021
# Batch 128/139, Loss: 1.7877, Accuracy: 0.5145
# Test Loss: 1.5767,  Accuracy: 0.5399
# Epoch 10/50
# -------------------------------
# Batch 16/139, Loss: 1.7112, Accuracy: 0.5111
# Batch 32/139, Loss: 1.5701, Accuracy: 0.5530
# Batch 48/139, Loss: 1.5657, Accuracy: 0.5516
# Batch 64/139, Loss: 1.6374, Accuracy: 0.5569
# Batch 80/139, Loss: 1.5633, Accuracy: 0.5426
# Batch 96/139, Loss: 1.5057, Accuracy: 0.5709
# Batch 112/139, Loss: 1.6433, Accuracy: 0.5387
# Batch 128/139, Loss: 1.6577, Accuracy: 0.5536
# Test Loss: 1.5389,  Accuracy: 0.5629
# Epoch 11/50
# -------------------------------
# Batch 16/139, Loss: 1.5892, Accuracy: 0.5555
# Batch 32/139, Loss: 1.5442, Accuracy: 0.5616
# Batch 48/139, Loss: 1.4818, Accuracy: 0.5866
# Batch 64/139, Loss: 1.6912, Accuracy: 0.5484
# Batch 80/139, Loss: 1.4934, Accuracy: 0.5752
# Batch 96/139, Loss: 1.4448, Accuracy: 0.5993
# Batch 112/139, Loss: 1.5383, Accuracy: 0.5758
# Batch 128/139, Loss: 1.5529, Accuracy: 0.5518
# Test Loss: 1.6419,  Accuracy: 0.5565
# Epoch 12/50
# -------------------------------
# Batch 16/139, Loss: 1.6574, Accuracy: 0.5401
# Batch 32/139, Loss: 1.5110, Accuracy: 0.5796
# Batch 48/139, Loss: 1.5063, Accuracy: 0.5709
# Batch 64/139, Loss: 1.4850, Accuracy: 0.5816
# Batch 80/139, Loss: 1.4951, Accuracy: 0.5717
# Batch 96/139, Loss: 1.4344, Accuracy: 0.6022
# Batch 112/139, Loss: 1.5010, Accuracy: 0.5816
# Batch 128/139, Loss: 1.5205, Accuracy: 0.5742
# Test Loss: 1.5182,  Accuracy: 0.5716
# Epoch 13/50
# -------------------------------
# Batch 16/139, Loss: 1.6152, Accuracy: 0.5592
# Batch 32/139, Loss: 1.5103, Accuracy: 0.5829
# Batch 48/139, Loss: 1.2730, Accuracy: 0.6162
# Batch 64/139, Loss: 1.5571, Accuracy: 0.5626
# Batch 80/139, Loss: 1.5989, Accuracy: 0.5656
# Batch 96/139, Loss: 1.4902, Accuracy: 0.5984
# Batch 112/139, Loss: 1.5836, Accuracy: 0.5695
# Batch 128/139, Loss: 1.4628, Accuracy: 0.5820
# Test Loss: 1.3966,  Accuracy: 0.6014
# Epoch 14/50
# -------------------------------
# Batch 16/139, Loss: 1.5248, Accuracy: 0.5561
# Batch 32/139, Loss: 1.4712, Accuracy: 0.5843
# Batch 48/139, Loss: 1.3434, Accuracy: 0.6177
# Batch 64/139, Loss: 1.5612, Accuracy: 0.5824
# Batch 80/139, Loss: 1.5297, Accuracy: 0.5757
# Batch 96/139, Loss: 1.4603, Accuracy: 0.5985
# Batch 112/139, Loss: 1.3975, Accuracy: 0.5989
# Batch 128/139, Loss: 1.4761, Accuracy: 0.5993
# Test Loss: 1.4112,  Accuracy: 0.6001
# Epoch 15/50
# -------------------------------
# Batch 16/139, Loss: 1.5987, Accuracy: 0.5553
# Batch 32/139, Loss: 1.4051, Accuracy: 0.5988
# Batch 48/139, Loss: 1.5746, Accuracy: 0.5554
# Batch 64/139, Loss: 1.4610, Accuracy: 0.5953
# Batch 80/139, Loss: 1.4619, Accuracy: 0.5963
# Batch 96/139, Loss: 1.4408, Accuracy: 0.5988
# Batch 112/139, Loss: 1.4278, Accuracy: 0.6001
# Batch 128/139, Loss: 1.2584, Accuracy: 0.6535
# Test Loss: 1.5563,  Accuracy: 0.5709
# Epoch 16/50
# -------------------------------
# Batch 16/139, Loss: 1.4391, Accuracy: 0.6017
# Batch 32/139, Loss: 1.4646, Accuracy: 0.6049
# Batch 48/139, Loss: 1.3586, Accuracy: 0.6235
# Batch 64/139, Loss: 1.3856, Accuracy: 0.6052
# Batch 80/139, Loss: 1.5948, Accuracy: 0.5706
# Batch 96/139, Loss: 1.4110, Accuracy: 0.6026
# Batch 112/139, Loss: 1.4676, Accuracy: 0.6042
# Batch 128/139, Loss: 1.4278, Accuracy: 0.6074
# Test Loss: 1.4553,  Accuracy: 0.5872
# Epoch 17/50
# -------------------------------
# Batch 16/139, Loss: 1.3755, Accuracy: 0.6171
# Batch 32/139, Loss: 1.5835, Accuracy: 0.5753
# Batch 48/139, Loss: 1.5249, Accuracy: 0.5833
# Batch 64/139, Loss: 1.4003, Accuracy: 0.6110
# Batch 80/139, Loss: 1.3595, Accuracy: 0.6047
# Batch 96/139, Loss: 1.3910, Accuracy: 0.6034
# Batch 112/139, Loss: 1.3583, Accuracy: 0.6181
# Batch 128/139, Loss: 1.4651, Accuracy: 0.5814
# Test Loss: 1.4277,  Accuracy: 0.6083
# Epoch 18/50
# -------------------------------
# Batch 16/139, Loss: 1.5237, Accuracy: 0.5975
# Batch 32/139, Loss: 1.5003, Accuracy: 0.5933
# Batch 48/139, Loss: 1.5322, Accuracy: 0.5941
# Batch 64/139, Loss: 1.7140, Accuracy: 0.5352
# Batch 80/139, Loss: 1.5642, Accuracy: 0.5839
# Batch 96/139, Loss: 1.4236, Accuracy: 0.6171
# Batch 112/139, Loss: 1.4804, Accuracy: 0.5929
# Batch 128/139, Loss: 1.3524, Accuracy: 0.6207
# Test Loss: 1.2761,  Accuracy: 0.6466
# Epoch 19/50
# -------------------------------
# Batch 16/139, Loss: 1.5195, Accuracy: 0.6092
# Batch 32/139, Loss: 1.4016, Accuracy: 0.6176
# Batch 48/139, Loss: 1.3870, Accuracy: 0.6299
# Batch 64/139, Loss: 1.3551, Accuracy: 0.6323
# Batch 80/139, Loss: 1.2337, Accuracy: 0.6507
# Batch 96/139, Loss: 1.4351, Accuracy: 0.6202
# Batch 112/139, Loss: 1.3926, Accuracy: 0.6329
# Batch 128/139, Loss: 1.3252, Accuracy: 0.6287
# Test Loss: 1.3883,  Accuracy: 0.6075
# Epoch 20/50
# -------------------------------
# Batch 16/139, Loss: 1.4138, Accuracy: 0.6020
# Batch 32/139, Loss: 1.3339, Accuracy: 0.6109
# Batch 48/139, Loss: 1.4685, Accuracy: 0.5881
# Batch 64/139, Loss: 1.4071, Accuracy: 0.6292
# Batch 80/139, Loss: 1.5533, Accuracy: 0.5657
# Batch 96/139, Loss: 1.3069, Accuracy: 0.6403
# Batch 112/139, Loss: 1.5090, Accuracy: 0.5844
# Batch 128/139, Loss: 1.4347, Accuracy: 0.6284
# Test Loss: 1.4235,  Accuracy: 0.6197
# Epoch 21/50
# -------------------------------
# Batch 16/139, Loss: 1.3713, Accuracy: 0.6211
# Batch 32/139, Loss: 1.3604, Accuracy: 0.6321
# Batch 48/139, Loss: 1.4088, Accuracy: 0.6235
# Batch 64/139, Loss: 1.4419, Accuracy: 0.6037
# Batch 80/139, Loss: 1.3071, Accuracy: 0.6500
# Batch 96/139, Loss: 1.3025, Accuracy: 0.6360
# Batch 112/139, Loss: 1.4419, Accuracy: 0.6145
# Batch 128/139, Loss: 1.3204, Accuracy: 0.6459
# Test Loss: 1.4512,  Accuracy: 0.6048
# Epoch 22/50
# -------------------------------
# Batch 16/139, Loss: 1.3494, Accuracy: 0.6316
# Batch 32/139, Loss: 1.5119, Accuracy: 0.5830
# Batch 48/139, Loss: 1.4491, Accuracy: 0.5959
# Batch 64/139, Loss: 1.3308, Accuracy: 0.6349
# Batch 80/139, Loss: 1.2894, Accuracy: 0.6391
# Batch 96/139, Loss: 1.4551, Accuracy: 0.6089
# Batch 112/139, Loss: 1.3164, Accuracy: 0.6464
# Batch 128/139, Loss: 1.3775, Accuracy: 0.6266
# Test Loss: 1.1696,  Accuracy: 0.6637
# Epoch 23/50
# -------------------------------
# Batch 16/139, Loss: 1.3990, Accuracy: 0.6193
# Batch 32/139, Loss: 1.2939, Accuracy: 0.6322
# Batch 48/139, Loss: 1.3297, Accuracy: 0.6175
# Batch 64/139, Loss: 1.2855, Accuracy: 0.6363
# Batch 80/139, Loss: 1.2740, Accuracy: 0.6444
# Batch 96/139, Loss: 1.2679, Accuracy: 0.6474
# Batch 112/139, Loss: 1.3778, Accuracy: 0.6146
# Batch 128/139, Loss: 1.3743, Accuracy: 0.6216
# Test Loss: 1.2634,  Accuracy: 0.6688
# Epoch 24/50
# -------------------------------
# Batch 16/139, Loss: 1.3612, Accuracy: 0.6228
# Batch 32/139, Loss: 1.3573, Accuracy: 0.6311
# Batch 48/139, Loss: 1.4432, Accuracy: 0.6035
# Batch 64/139, Loss: 1.1909, Accuracy: 0.6787
# Batch 80/139, Loss: 1.4498, Accuracy: 0.6160
# Batch 96/139, Loss: 1.2912, Accuracy: 0.6310
# Batch 112/139, Loss: 1.4557, Accuracy: 0.6014
# Batch 128/139, Loss: 1.3700, Accuracy: 0.6141
# Test Loss: 1.3517,  Accuracy: 0.6236
# Epoch 25/50
# -------------------------------
# Batch 16/139, Loss: 1.3801, Accuracy: 0.6098
# Batch 32/139, Loss: 1.4079, Accuracy: 0.6290
# Batch 48/139, Loss: 1.4179, Accuracy: 0.6123
# Batch 64/139, Loss: 1.3692, Accuracy: 0.6270
# Batch 80/139, Loss: 1.4268, Accuracy: 0.6068
# Batch 96/139, Loss: 1.4879, Accuracy: 0.6020
# Batch 112/139, Loss: 1.3591, Accuracy: 0.6154
# Batch 128/139, Loss: 1.3657, Accuracy: 0.6253
# Test Loss: 1.3539,  Accuracy: 0.6260
# Epoch 26/50
# -------------------------------
# Batch 16/139, Loss: 1.3782, Accuracy: 0.6340
# Batch 32/139, Loss: 1.2977, Accuracy: 0.6405
# Batch 48/139, Loss: 1.2526, Accuracy: 0.6622
# Batch 64/139, Loss: 1.2391, Accuracy: 0.6653
# Batch 80/139, Loss: 1.3893, Accuracy: 0.6068
# Batch 96/139, Loss: 1.3867, Accuracy: 0.6175
# Batch 112/139, Loss: 1.3174, Accuracy: 0.6256
# Batch 128/139, Loss: 1.2697, Accuracy: 0.6459
# Test Loss: 1.3072,  Accuracy: 0.6432
# Epoch 27/50
# -------------------------------
# Batch 16/139, Loss: 1.3490, Accuracy: 0.6437
# Batch 32/139, Loss: 1.3521, Accuracy: 0.6362
# Batch 48/139, Loss: 1.3421, Accuracy: 0.6287
# Batch 64/139, Loss: 1.3413, Accuracy: 0.6382
# Batch 80/139, Loss: 1.4097, Accuracy: 0.6240
# Batch 96/139, Loss: 1.3819, Accuracy: 0.6232
# Batch 112/139, Loss: 1.3178, Accuracy: 0.6427
# Batch 128/139, Loss: 1.3857, Accuracy: 0.6195
# Test Loss: 1.3044,  Accuracy: 0.6529
# Epoch 28/50
# -------------------------------
# Batch 16/139, Loss: 1.3189, Accuracy: 0.6356
# Batch 32/139, Loss: 1.3620, Accuracy: 0.6254
# Batch 48/139, Loss: 1.3265, Accuracy: 0.6425
# Batch 64/139, Loss: 1.1917, Accuracy: 0.6576
# Batch 80/139, Loss: 1.2614, Accuracy: 0.6514
# Batch 96/139, Loss: 1.3205, Accuracy: 0.6397
# Batch 112/139, Loss: 1.4529, Accuracy: 0.6044
# Batch 128/139, Loss: 1.2690, Accuracy: 0.6383
# Test Loss: 1.1870,  Accuracy: 0.6669
# Epoch 29/50
# -------------------------------
# Batch 16/139, Loss: 1.4661, Accuracy: 0.6009
# Batch 32/139, Loss: 1.2388, Accuracy: 0.6558
# Batch 48/139, Loss: 1.4261, Accuracy: 0.6107
# Batch 64/139, Loss: 1.3208, Accuracy: 0.6310
# Batch 80/139, Loss: 1.2324, Accuracy: 0.6642
# Batch 96/139, Loss: 1.1815, Accuracy: 0.6716
# Batch 112/139, Loss: 1.2061, Accuracy: 0.6606
# Batch 128/139, Loss: 1.3528, Accuracy: 0.6308
# Test Loss: 1.2710,  Accuracy: 0.6555
# Epoch 30/50
# -------------------------------
# Batch 16/139, Loss: 1.3586, Accuracy: 0.6148
# Batch 32/139, Loss: 1.3594, Accuracy: 0.6304
# Batch 48/139, Loss: 1.3515, Accuracy: 0.6284
# Batch 64/139, Loss: 1.2811, Accuracy: 0.6400
# Batch 80/139, Loss: 1.3952, Accuracy: 0.6135
# Batch 96/139, Loss: 1.2730, Accuracy: 0.6438
# Batch 112/139, Loss: 1.3988, Accuracy: 0.6157
# Batch 128/139, Loss: 1.2791, Accuracy: 0.6469
# Test Loss: 1.2902,  Accuracy: 0.6450
# Epoch 31/50
# -------------------------------
# Batch 16/139, Loss: 1.4757, Accuracy: 0.6025
# Batch 32/139, Loss: 1.3413, Accuracy: 0.6335
# Batch 48/139, Loss: 1.3512, Accuracy: 0.6421
# Batch 64/139, Loss: 1.4046, Accuracy: 0.6249
# Batch 80/139, Loss: 1.2597, Accuracy: 0.6470
# Batch 96/139, Loss: 1.3356, Accuracy: 0.6202
# Batch 112/139, Loss: 1.3579, Accuracy: 0.6294
# Batch 128/139, Loss: 1.4615, Accuracy: 0.6324
# Test Loss: 1.1965,  Accuracy: 0.6558
# Epoch 32/50
# -------------------------------
# Batch 16/139, Loss: 1.3046, Accuracy: 0.6078
# Batch 32/139, Loss: 1.3401, Accuracy: 0.6343
# Batch 48/139, Loss: 1.2508, Accuracy: 0.6399
# Batch 64/139, Loss: 1.3872, Accuracy: 0.6286
# Batch 80/139, Loss: 1.2904, Accuracy: 0.6308
# Batch 96/139, Loss: 1.3274, Accuracy: 0.6267
# Batch 112/139, Loss: 1.3416, Accuracy: 0.6408
# Batch 128/139, Loss: 1.3042, Accuracy: 0.6323
# Test Loss: 1.3348,  Accuracy: 0.6440
# Epoch 33/50
# -------------------------------
# Batch 16/139, Loss: 1.3234, Accuracy: 0.6523
# Batch 32/139, Loss: 1.4170, Accuracy: 0.6170
# Batch 48/139, Loss: 1.2654, Accuracy: 0.6381
# Batch 64/139, Loss: 1.3964, Accuracy: 0.6282
# Batch 80/139, Loss: 1.4035, Accuracy: 0.6012
# Batch 96/139, Loss: 1.2777, Accuracy: 0.6466
# Batch 112/139, Loss: 1.3200, Accuracy: 0.6315
# Batch 128/139, Loss: 1.5427, Accuracy: 0.6009
# Test Loss: 1.1989,  Accuracy: 0.6755
# Epoch 34/50
# -------------------------------
# Batch 16/139, Loss: 1.3796, Accuracy: 0.6210
# Batch 32/139, Loss: 1.3519, Accuracy: 0.6351
# Batch 48/139, Loss: 1.3040, Accuracy: 0.6307
# Batch 64/139, Loss: 1.3253, Accuracy: 0.6421
# Batch 80/139, Loss: 1.2931, Accuracy: 0.6475
# Batch 96/139, Loss: 1.2674, Accuracy: 0.6457
# Batch 112/139, Loss: 1.4649, Accuracy: 0.6063
# Batch 128/139, Loss: 1.3423, Accuracy: 0.6277
# Test Loss: 1.2501,  Accuracy: 0.6574
# Epoch 35/50
# -------------------------------
# Batch 16/139, Loss: 1.2790, Accuracy: 0.6540
# Batch 32/139, Loss: 1.2694, Accuracy: 0.6389
# Batch 48/139, Loss: 1.3834, Accuracy: 0.6063
# Batch 64/139, Loss: 1.2530, Accuracy: 0.6585
# Batch 80/139, Loss: 1.4068, Accuracy: 0.6148
# Batch 96/139, Loss: 1.3707, Accuracy: 0.6234
# Batch 112/139, Loss: 1.3402, Accuracy: 0.6304
# Batch 128/139, Loss: 1.4848, Accuracy: 0.6062
# Test Loss: 1.2871,  Accuracy: 0.6366
# Epoch 36/50
# -------------------------------
# Batch 16/139, Loss: 1.4014, Accuracy: 0.6143
# Batch 32/139, Loss: 1.3722, Accuracy: 0.6191
# Batch 48/139, Loss: 1.2945, Accuracy: 0.6337
# Batch 64/139, Loss: 1.4194, Accuracy: 0.6055
# Batch 80/139, Loss: 1.3484, Accuracy: 0.6392
# Batch 96/139, Loss: 1.3863, Accuracy: 0.6134
# Batch 112/139, Loss: 1.3287, Accuracy: 0.6456
# Batch 128/139, Loss: 1.3788, Accuracy: 0.6298
# Test Loss: 1.2250,  Accuracy: 0.6697
# Epoch 37/50
# -------------------------------
# Batch 16/139, Loss: 1.2721, Accuracy: 0.6553
# Batch 32/139, Loss: 1.3915, Accuracy: 0.6198
# Batch 48/139, Loss: 1.3309, Accuracy: 0.6401
# Batch 64/139, Loss: 1.4214, Accuracy: 0.6155
# Batch 80/139, Loss: 1.2847, Accuracy: 0.6600
# Batch 96/139, Loss: 1.3277, Accuracy: 0.6426
# Batch 112/139, Loss: 1.3636, Accuracy: 0.6273
# Batch 128/139, Loss: 1.2220, Accuracy: 0.6612
# Test Loss: 1.3096,  Accuracy: 0.6469
# Epoch 38/50
# -------------------------------
# Batch 16/139, Loss: 1.4057, Accuracy: 0.6153
# Batch 32/139, Loss: 1.3234, Accuracy: 0.6372
# Batch 48/139, Loss: 1.4154, Accuracy: 0.6246
# Batch 64/139, Loss: 1.4265, Accuracy: 0.6029
# Batch 80/139, Loss: 1.3107, Accuracy: 0.6467
# Batch 96/139, Loss: 1.2189, Accuracy: 0.6712
# Batch 112/139, Loss: 1.3404, Accuracy: 0.6189
# Batch 128/139, Loss: 1.2636, Accuracy: 0.6470
# Test Loss: 1.2711,  Accuracy: 0.6516
# Epoch 39/50
# -------------------------------
# Batch 16/139, Loss: 1.3588, Accuracy: 0.6371
# Batch 32/139, Loss: 1.3748, Accuracy: 0.6230
# Batch 48/139, Loss: 1.3102, Accuracy: 0.6393
# Batch 64/139, Loss: 1.3345, Accuracy: 0.6320
# Batch 80/139, Loss: 1.3153, Accuracy: 0.6549
# Batch 96/139, Loss: 1.4536, Accuracy: 0.6097
# Batch 112/139, Loss: 1.2371, Accuracy: 0.6532
# Batch 128/139, Loss: 1.2247, Accuracy: 0.6564
# Test Loss: 1.2210,  Accuracy: 0.6650
# Epoch 40/50
# -------------------------------
# Batch 16/139, Loss: 1.3572, Accuracy: 0.6383
# Batch 32/139, Loss: 1.2192, Accuracy: 0.6622
# Batch 48/139, Loss: 1.3643, Accuracy: 0.6224
# Batch 64/139, Loss: 1.3232, Accuracy: 0.6409
# Batch 80/139, Loss: 1.3405, Accuracy: 0.6223
# Batch 96/139, Loss: 1.3244, Accuracy: 0.6453
# Batch 112/139, Loss: 1.3217, Accuracy: 0.6222
# Batch 128/139, Loss: 1.2453, Accuracy: 0.6690
# Test Loss: 1.2738,  Accuracy: 0.6581
# Epoch 41/50
# -------------------------------
# Batch 16/139, Loss: 1.4511, Accuracy: 0.6166
# Batch 32/139, Loss: 1.4107, Accuracy: 0.6169
# Batch 48/139, Loss: 1.2843, Accuracy: 0.6555
# Batch 64/139, Loss: 1.3051, Accuracy: 0.6412
# Batch 80/139, Loss: 1.3242, Accuracy: 0.6285
# Batch 96/139, Loss: 1.1756, Accuracy: 0.6848
# Batch 112/139, Loss: 1.3934, Accuracy: 0.6287
# Batch 128/139, Loss: 1.1895, Accuracy: 0.6703
# Test Loss: 1.2563,  Accuracy: 0.6509
# Epoch 42/50
# -------------------------------
# Batch 16/139, Loss: 1.3256, Accuracy: 0.6352
# Batch 32/139, Loss: 1.3130, Accuracy: 0.6388
# Batch 48/139, Loss: 1.3164, Accuracy: 0.6569
# Batch 64/139, Loss: 1.2072, Accuracy: 0.6567
# Batch 80/139, Loss: 1.3334, Accuracy: 0.6417
# Batch 96/139, Loss: 1.2454, Accuracy: 0.6388
# Batch 112/139, Loss: 1.2207, Accuracy: 0.6513
# Batch 128/139, Loss: 1.5077, Accuracy: 0.6012
# Test Loss: 1.4111,  Accuracy: 0.6274
# Epoch 43/50
# -------------------------------
# Batch 16/139, Loss: 1.3160, Accuracy: 0.6421
# Batch 32/139, Loss: 1.3953, Accuracy: 0.6120
# Batch 48/139, Loss: 1.1937, Accuracy: 0.6602
# Batch 64/139, Loss: 1.3103, Accuracy: 0.6286
# Batch 80/139, Loss: 1.3587, Accuracy: 0.6398
# Batch 96/139, Loss: 1.2406, Accuracy: 0.6743
# Batch 112/139, Loss: 1.4067, Accuracy: 0.6238
# Batch 128/139, Loss: 1.3962, Accuracy: 0.6119
# Test Loss: 1.2588,  Accuracy: 0.6584
# Epoch 44/50
# -------------------------------
# Batch 16/139, Loss: 1.3594, Accuracy: 0.6161
# Batch 32/139, Loss: 1.3599, Accuracy: 0.6278
# Batch 48/139, Loss: 1.2938, Accuracy: 0.6454
# Batch 64/139, Loss: 1.3827, Accuracy: 0.6222
# Batch 80/139, Loss: 1.2593, Accuracy: 0.6382
# Batch 96/139, Loss: 1.4473, Accuracy: 0.6088
# Batch 112/139, Loss: 1.3025, Accuracy: 0.6428
# Batch 128/139, Loss: 1.3749, Accuracy: 0.6260
# Test Loss: 1.2618,  Accuracy: 0.6554
# Epoch 45/50
# -------------------------------
# Batch 16/139, Loss: 1.3948, Accuracy: 0.6193
# Batch 32/139, Loss: 1.3041, Accuracy: 0.6447
# Batch 48/139, Loss: 1.2894, Accuracy: 0.6533
# Batch 64/139, Loss: 1.1707, Accuracy: 0.6813
# Batch 80/139, Loss: 1.3546, Accuracy: 0.6359
# Batch 96/139, Loss: 1.3041, Accuracy: 0.6455
# Batch 112/139, Loss: 1.2977, Accuracy: 0.6502
# Batch 128/139, Loss: 1.3078, Accuracy: 0.6485
# Test Loss: 1.2987,  Accuracy: 0.6516
# Epoch 46/50
# -------------------------------
# Batch 16/139, Loss: 1.2686, Accuracy: 0.6380
# Batch 32/139, Loss: 1.1667, Accuracy: 0.6756
# Batch 48/139, Loss: 1.4284, Accuracy: 0.6179
# Batch 64/139, Loss: 1.2455, Accuracy: 0.6565
# Batch 80/139, Loss: 1.2303, Accuracy: 0.6777
# Batch 96/139, Loss: 1.3743, Accuracy: 0.6171
# Batch 112/139, Loss: 1.3092, Accuracy: 0.6509
# Batch 128/139, Loss: 1.2581, Accuracy: 0.6480
# Test Loss: 1.2306,  Accuracy: 0.6730
# Epoch 47/50
# -------------------------------
# Batch 16/139, Loss: 1.2882, Accuracy: 0.6469
# Batch 32/139, Loss: 1.3620, Accuracy: 0.6246
# Batch 48/139, Loss: 1.2671, Accuracy: 0.6391
# Batch 64/139, Loss: 1.4292, Accuracy: 0.6187
# Batch 80/139, Loss: 1.3474, Accuracy: 0.6416
# Batch 96/139, Loss: 1.3257, Accuracy: 0.6392
# Batch 112/139, Loss: 1.5463, Accuracy: 0.6025
# Batch 128/139, Loss: 1.2829, Accuracy: 0.6496
# Test Loss: 1.1661,  Accuracy: 0.6707
# Epoch 48/50
# -------------------------------
# Batch 16/139, Loss: 1.3000, Accuracy: 0.6491
# Batch 32/139, Loss: 1.4166, Accuracy: 0.6271
# Batch 48/139, Loss: 1.3483, Accuracy: 0.6366
# Batch 64/139, Loss: 1.2767, Accuracy: 0.6536
# Batch 80/139, Loss: 1.3797, Accuracy: 0.6274
# Batch 96/139, Loss: 1.3301, Accuracy: 0.6392
# Batch 112/139, Loss: 1.4668, Accuracy: 0.6087
# Batch 128/139, Loss: 1.3257, Accuracy: 0.6427
# Test Loss: 1.2329,  Accuracy: 0.6712
# Epoch 49/50
# -------------------------------
# Batch 16/139, Loss: 1.4017, Accuracy: 0.6239
# Batch 32/139, Loss: 1.2991, Accuracy: 0.6585
# Batch 48/139, Loss: 1.2918, Accuracy: 0.6346
# Batch 64/139, Loss: 1.2980, Accuracy: 0.6373
# Batch 80/139, Loss: 1.4181, Accuracy: 0.6131
# Batch 96/139, Loss: 1.2086, Accuracy: 0.6651
# Batch 112/139, Loss: 1.2127, Accuracy: 0.6533
# Batch 128/139, Loss: 1.4813, Accuracy: 0.6056
# Test Loss: 1.1891,  Accuracy: 0.6545
# Epoch 50/50
# -------------------------------
# Batch 16/139, Loss: 1.2824, Accuracy: 0.6409
# Batch 32/139, Loss: 1.2297, Accuracy: 0.6572
# Batch 48/139, Loss: 1.3345, Accuracy: 0.6260
# Batch 64/139, Loss: 1.1778, Accuracy: 0.6822
# Batch 80/139, Loss: 1.4166, Accuracy: 0.6180
# Batch 96/139, Loss: 1.2298, Accuracy: 0.6412
# Batch 112/139, Loss: 1.5178, Accuracy: 0.6053
# Batch 128/139, Loss: 1.3509, Accuracy: 0.6356
# Test Loss: 1.3143,  Accuracy: 0.6363

# %%
# Save the model
torch.save(conditional_transformer.state_dict(), "../Models/CondTransformerS.pt")

# %% [markdown]
# ## Inference

# %%
from src import *

parser = chord_parser.Main()
interpreter = seq_interpreter.Main(parser)

# %%
def pad(chords):
    """Pad the input 2D tensor [n] into shape [256] with zeros without the end of sequence token"""
    out = torch.zeros((256))
    out[0] = VOCAB_SIZE - 2 # Start of sequence token
    out[1:len(chords) + 1] = chords
    return out

# %%
dataset.all_genres, dataset.all_decades
# Out:
# (array(['Rock', 'Folk', 'Pop', 'Soundtrack', 'R&B, Funk & Soul', 'Country',
#         'Jazz', 'Experimental', 'Religious Music', 'Reggae & Ska',
#         'Hip Hop', 'Electronic', 'Comedy', 'Metal', 'Blues', 'World Music',
#         'Disco', 'Classical', 'New Age', 'Darkwave'], dtype=object),
#  array([1990, 2010, 1960, 1970, 2000, 1980, 2020, 1950], dtype=int64))

# %%
def generate_sequence(temperature, max_length, genres, decade):
    conditional_transformer.eval()
    with torch.inference_mode():
        x = torch.zeros((1, max_length + 1), dtype=torch.long, device=device)
        
        style = dataset.multi_hot(genres, decade).unsqueeze(0)
        for i in range(max_length):
            input_x = x[:, :i].squeeze(0)
            input_x = pad(input_x).long().unsqueeze(0)
            y_pred = conditional_transformer(input_x.to(device), style.to(device)).squeeze()[i]
            # Zero out the probability for the same as the previous chord
            if i > 0:
                y_pred[x[:, i - 1]] = -torch.inf
            # Sample from the distribution
            y_pred = F.softmax(y_pred, dim=0) ** (1 / temperature)
            x[:, i] = y_pred.multinomial(1).item()
            if x[:, i] == VOCAB_SIZE - 1:
                break
        if VOCAB_SIZE - 1 not in x:
            x[:, -1] = VOCAB_SIZE - 1
    return x[0]

# %%
seq = generate_sequence(1.0, 256, ["Jazz"], 1970)
print(interpreter.token_seq_to_chords(seq))
interpreter.play_seq(seq)
# Out:
# d:\Programs\anaconda3\lib\site-packages\torch\nn\modules\activation.py:1144: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\attention.cpp:152.)
#   return torch._native_multi_head_attention(
# F# | A6 | B | F#m | Emaj7 | A | B | A | B | E | B7 | E | B7 | E | B7 | E | F# | B | A | B | E | B7 | F#7 | B | A | B | A | B | E | A# | B | A | B | F# | E | B | C#m | F# | B | A | B | E | Am | G#m | Bm | G#m | Bm | F# | B | A | B | E
#                 <div id="midiPlayerDiv268"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv268");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>
