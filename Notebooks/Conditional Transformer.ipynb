# %% [markdown]
# # Conditional Generation with Transformers

# %%
import json
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchinfo import summary

# %%
data = pd.read_csv('../Data/data_tokenized_pitch_class.csv')
data["chords"] = data["chords"].apply(lambda x: torch.tensor(json.loads(x)))
data.head()
# Out:
#                                                  url  \
# 0  https://tabs.ultimate-guitar.com/tab/jeff-buck...
# 1  https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 2  https://tabs.ultimate-guitar.com/tab/elvis-pre...
# 3  https://tabs.ultimate-guitar.com/tab/eagles/ho...
# 4  https://tabs.ultimate-guitar.com/tab/radiohead...
#
#                        title         artist  decade  \
# 0                 Hallelujah   Jeff Buckley    1990
# 1                    Perfect     Ed Sheeran    2010
# 2  Cant Help Falling In Love  Elvis Presley    1960
# 3           Hotel California         Eagles    1970
# 4                      Creep      Radiohead    1990
#
#                          genre  ratings  stars  \
# 0                    Rock|Folk  51639.0    5.0
# 1                          Pop  44194.0    5.0
# 2  Soundtrack|R&B, Funk & Soul  30059.0    5.0
# 3                         Rock  28670.0    5.0
# 4                         Rock  28606.0    5.0
#
#                                               chords
# 0  [tensor(685), tensor(677), tensor(685), tensor...
# 1  [tensor(162), tensor(34), tensor(685), tensor(...
# 2  [tensor(685), tensor(162), tensor(677), tensor...
# 3  [tensor(173), tensor(422), tensor(397), tensor...
# 4  [tensor(162), tensor(83), tensor(685), tensor(...

# %%
augmentation_map = torch.tensor(np.load('../Data/augmentation_map.npy', allow_pickle=True))

with open("../Data/token_to_chord.json", "r") as f:
    token_to_chord = json.load(f)
# Convert the dictionary keys to integers
token_to_chord = {int(k): v for k, v in token_to_chord.items()}

# %%
VOCAB_SIZE = len(token_to_chord) + 2
VOCAB_SIZE
# Out:
# 1035

# %% [markdown]
# ## Dataset

# %%
class ChordDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.all_genres = data["genre"].apply(lambda x: x.split("|")).explode().unique()
        self.all_decades = data["decade"].unique()
        self.genre_to_idx = {genre: i for i, genre in enumerate(self.all_genres)}
        self.decade_to_idx = {decade: i for i, decade in enumerate(self.all_decades)}

        self.style_dim = len(self.all_genres) + len(self.all_decades)
    
    def augment(self, chords):
        """Change the root note of the chords by a random amount"""
        move_by = torch.randint(0, 12, [1]).item()
        return augmentation_map[chords, move_by]
        
    def pad(self, chords):
        """Pad the input tensor of shape [n] into shape [256] with zeros and special tokens"""
        out = torch.zeros((256))
        out[0] = VOCAB_SIZE - 2 # Start of sequence token
        out[1:len(chords) + 1] = chords
        out[len(chords) + 1] = VOCAB_SIZE - 1 # End of sequence token
        return out

    def multi_hot(self, genres, decade):
        """Convert a list of genres and a decade into a multi-hot vector"""
        genre_style = torch.zeros((len(self.all_genres)))
        genre_style[[self.genre_to_idx[genre] for genre in genres]] = 1
        genre_style /= genre_style.sum() # Normalize as there can be multiple genres
        
        decade_style = torch.zeros((len(self.all_decades)))
        decade_style[self.decade_to_idx[decade]] = 1
        
        return torch.cat([genre_style, decade_style])
        
    def __getitem__(self, index):
        row = self.data.iloc[index]
        x = self.augment(row["chords"])
        x = self.pad(x).long()
        
        genres = self.multi_hot(row["genre"].split("|"), row["decade"])
        
        return x, genres

    def __len__(self):
        return len(self.data)

# %%
torch.manual_seed(42)

dataset = ChordDataset(data)
train_size = np.rint(len(dataset) * 0.8).astype(int)
train_data, test_data = random_split(dataset, [train_size, len(dataset) - train_size])

# %%
# Define the dataloaders
train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
test_loader = DataLoader(test_data, batch_size=128, shuffle=True)

# %% [markdown]
# ## Model

# %%
class AdaptiveLayerNorm(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.norm = nn.LayerNorm(d_model)
        self.gain = nn.Linear(d_model, d_model)
        self.bias = nn.Linear(d_model, d_model)            
        
    def forward(self, x, style):
        gain = self.gain(F.relu(style)).unsqueeze(1).repeat(1, x.shape[1], 1)
        bias = self.bias(F.relu(style)).unsqueeze(1).repeat(1, x.shape[1], 1)
        return (1 + gain) * self.norm(x) + bias
                 

class TransformerBlock(nn.Module):
    def __init__(self, d_model, n_heads):
        super().__init__()
        self.layer_norm1 = AdaptiveLayerNorm(d_model)
        self.multi_head_attention = nn.MultiheadAttention(
            embed_dim=d_model, num_heads=n_heads, batch_first=True
        )
        self.dropout1 = nn.Dropout(0.1)
        self.layer_norm2 = AdaptiveLayerNorm(d_model)
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, d_model * 4), nn.ReLU(), nn.Linear(d_model * 4, d_model)
        )
        self.dropout2 = nn.Dropout(0.1)

    def forward(self, x, style, mask=None):
        # Multi-head attention
        att_input = self.layer_norm1(x, style)
        att_output = self.multi_head_attention(att_input, att_input, att_input, attn_mask=mask, need_weights=False)[0]
        x = x + self.dropout1(att_output)

        # Feed forward
        ff_input = self.layer_norm2(x, style)
        ff_output = self.feed_forward(ff_input)
        x = x + self.dropout2(ff_output)
        
        return x 


class ConditionalTransformer(nn.Module):
    def __init__(self, d_model, n_heads, n_layers, input_len):
        super().__init__()
        self.style_map = nn.Linear(dataset.style_dim, d_model)
        self.embedding = nn.Embedding(VOCAB_SIZE, d_model)
        self.transformer_blocks = nn.ModuleList([TransformerBlock(d_model, n_heads) for _ in range(n_layers)])
        self.output = nn.Linear(d_model, VOCAB_SIZE)

        # Positional encoding
        self.register_buffer('pe', torch.zeros(input_len, d_model))
        self.pe = torch.zeros(input_len, d_model)
        pos = torch.arange(0, input_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model)
        )
        self.pe[:, 0::2] = torch.sin(pos * div_term)
        self.pe[:, 1::2] = torch.cos(pos * div_term)
        

    def generate_square_subsequent_mask(self, size):
        """Generate a boolean mask to avoid attending to future tokens."""
        mask = torch.triu(torch.ones(size, size), diagonal=1).bool()
        return mask

    def forward(self, x, style):
        x = self.embedding(x)
        style = self.style_map(style)
        x = x + self.pe
        
        # Generate mask
        mask = self.generate_square_subsequent_mask(x.size(1)).to(x.device)
        
        # Passing through all transformer blocks
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x, style, mask)
        x = self.output(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# The hyperparameters are the same as for the basic Transformer architecture:
# * CondTransformerS: `d_model` = 64, `n_heads` = 8, `n_layers` = 6 (527k total params)
# * CondTransformerM: `d_model` = 80, `n_heads` = 10, `n_layers` = 12 (1.404M total params)
# * CondTransformerL: `d_model` = 96, `n_heads` = 12, `n_layers` = 24 (3.769M total params)

# %%
conditional_transformer = ConditionalTransformer(
    d_model=64,
    n_heads=8,
    n_layers=6,
    input_len=256
).to(device)
dummy_input = torch.zeros((1, 256), dtype=torch.long).to(device)
dummy_style = torch.zeros((1, dataset.style_dim)).to(device)
summary(conditional_transformer, input_data=(dummy_input, dummy_style))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ConditionalTransformer                   [1, 256, 1035]            --
# ├─Embedding: 1-1                         [1, 256, 64]              66,240
# ├─Linear: 1-2                            [1, 64]                   1,856
# ├─ModuleList: 1-3                        --                        --
# │    └─TransformerBlock: 2-1             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-1       [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-2      [1, 256, 64]              16,640
# │    │    └─Dropout: 3-3                 [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-4       [1, 256, 64]              8,448
# │    │    └─Sequential: 3-5              [1, 256, 64]              33,088
# │    │    └─Dropout: 3-6                 [1, 256, 64]              --
# │    └─TransformerBlock: 2-2             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-7       [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-8      [1, 256, 64]              16,640
# │    │    └─Dropout: 3-9                 [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-10      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-11             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-12                [1, 256, 64]              --
# │    └─TransformerBlock: 2-3             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-13      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-14     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-15                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-16      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-17             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-18                [1, 256, 64]              --
# │    └─TransformerBlock: 2-4             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-19      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-20     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-21                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-22      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-23             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-24                [1, 256, 64]              --
# │    └─TransformerBlock: 2-5             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-25      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-26     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-27                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-28      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-29             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-30                [1, 256, 64]              --
# │    └─TransformerBlock: 2-6             [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-31      [1, 256, 64]              8,448
# │    │    └─MultiheadAttention: 3-32     [1, 256, 64]              16,640
# │    │    └─Dropout: 3-33                [1, 256, 64]              --
# │    │    └─AdaptiveLayerNorm: 3-34      [1, 256, 64]              8,448
# │    │    └─Sequential: 3-35             [1, 256, 64]              33,088
# │    │    └─Dropout: 3-36                [1, 256, 64]              --
# ├─Linear: 1-4                            [1, 256, 1035]            67,275
# ==========================================================================================
# Total params: 535,115
# Trainable params: 535,115
# Non-trainable params: 0
# Total mult-adds (M): 0.44
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 7.77
# Params size (MB): 1.74
# Estimated Total Size (MB): 9.51
# ==========================================================================================

# %% [markdown]
# ## Trainer

# %%
class Trainer():
    def __init__(self, epochs, train_loader, test_loader, model, optimizer, device, lr_scheduler):
        self.epochs = epochs
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.model = model
        self.optimizer = optimizer
        self.device = device
        self.print_every = 16
        self.lr_scheduler = lr_scheduler
        
        self.step_data = {"train_losses": [], "test_losses": [],  "train_accuracies": [], "test_accuracies": []}
        self.epoch_data = {"train_losses": [], "test_losses": [], "train_accuracies": [], "test_accuracies": []}
    

    def loss_mask(self, y_pred, x):
        """Get the mask for the loss function"""
        eos_index = torch.argmax((x == VOCAB_SIZE - 1).float(), dim=1)
        range_tensor = torch.arange(y_pred.shape[1]).unsqueeze(0).expand(y_pred.shape[0], -1).to(self.device)
        mask = range_tensor <= eos_index.unsqueeze(1)
        return mask
    
    def masked_accuracy(self, y_pred, x):
        """Calculate the accuracy of the model for elements of the sequence"""
        y_pred, x = y_pred[:, :-1], x[:, 1:]
        eos_index = torch.argmax((x == VOCAB_SIZE - 1).float(), dim=1)
        range_tensor = torch.arange(y_pred.shape[1]).unsqueeze(0).expand(y_pred.shape[0], -1).to(self.device)
        # EOS is not included in the accuracy calculation
        mask = range_tensor < eos_index.unsqueeze(1)
        valid_elements = torch.sum(mask.float())

        same = torch.argmax(y_pred, dim=2) == x
            
        return torch.sum(same.float() * mask.float()) / valid_elements
    
    def masked_cross_entropy(self, logits, target, mask):
        """
        logits: Predictions from the model, of shape (batch_size, sequence_length, num_classes)
        target: Ground truth labels, of shape (batch_size, sequence_length)
        mask: Binary mask indicating the non-padded parts, of shape (batch_size, sequence_length)
        """
        # Flatten all the dimensions except for the classes dimension
        logits_flat = logits.reshape(-1, logits.size(-1))
        target_flat = target.reshape(-1)
        mask_flat = mask.reshape(-1).float()
        
        # Compute the CrossEntropyLoss
        loss = nn.CrossEntropyLoss(reduction='none')(logits_flat, target_flat)
        
        # Apply the mask to the loss
        masked_loss = loss * mask_flat
        
        # Compute the mean loss over non-padded parts
        final_loss = masked_loss.sum() / mask_flat.sum()
        
        return final_loss

    
    def train_step(self):
        self.model.train()
        for i, (x, style) in enumerate(self.train_loader):
            x, style = x.to(self.device), style.to(self.device)
            y_pred = self.model(x, style)
            mask = self.loss_mask(y_pred, x)
            
            loss = self.masked_cross_entropy(y_pred[:, :-1], x[:, 1:], mask[:, :-1])
            self.step_data["train_losses"].append(loss.item())
            self.step_data["train_accuracies"].append(self.masked_accuracy(y_pred, x).item())

            if i % self.print_every == self.print_every - 1:
                print(f"Batch {i + 1}/{len(self.train_loader)}, Loss: {loss.item():.4f}, Accuracy: {self.step_data['train_accuracies'][-1]:.4f}")
                            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            
        self.epoch_data["train_losses"].append(np.array(self.step_data["train_losses"]).mean())
        self.epoch_data["train_accuracies"].append(np.array(self.step_data["train_accuracies"]).mean())
                   
        
    def eval_step(self):
        self.model.eval()
        for i, (x, style) in enumerate(self.train_loader):
            x, style = x.to(self.device), style.to(self.device)
            with torch.inference_mode():
                y_pred = self.model(x, style)

            mask = self.loss_mask(y_pred, x)            
            loss = self.masked_cross_entropy(y_pred[:, :-1], x[:, 1:], mask[:, :-1])
            self.step_data["test_losses"].append(loss.item())
            self.step_data["test_accuracies"].append(self.masked_accuracy(y_pred, x).item())
        
        self.epoch_data["test_losses"].append(np.array(self.step_data["test_losses"]).mean())
        self.epoch_data["test_accuracies"].append(np.array(self.step_data["test_accuracies"]).mean())
                    
        
        print(f"Test Loss: {loss.item():.4f},  Accuracy: {self.step_data['test_accuracies'][-1]:.4f}")

    def plot(self):
        fig, axes = plt.subplots(2, 1, figsize=(15, 15))
        axes[0].set_title("Loss")
        sns.lineplot(x=range(len(self.epoch_data["train_losses"])), y=self.epoch_data["train_losses"], label="Train Loss", ax=axes[0])
        sns.lineplot(x=range(len(self.epoch_data["test_losses"])), y=self.epoch_data["test_losses"], label="Test Loss", ax=axes[0])
        
        axes[1].set_title("Total Accuracy")
        sns.lineplot(x=range(len(self.epoch_data["train_accuracies"])), y=self.epoch_data["train_accuracies"], label="Train Accuracy", ax=axes[1])
        sns.lineplot(x=range(len(self.epoch_data["test_accuracies"])), y=self.epoch_data["test_accuracies"], label="Test Accuracy", ax=axes[1])
        
    
    def init_metrics(self):
        self.step_data = {"train_losses": [], "test_losses": [], "train_accuracies": [], "test_accuracies": []}

        
    def train(self):    
        for epoch in range(self.epochs):
            print(f"Epoch {epoch + 1}/{self.epochs}\n-------------------------------")
            self.init_metrics()
            self.train_step()
            self.eval_step()
            self.lr_scheduler.step()
            
        self.plot()

# %% [markdown]
# ## Training

# %%
optimizer = torch.optim.Adam(conditional_transformer.parameters(), lr=0.001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.3)
trainer = Trainer(
    epochs=50,
    train_loader=train_loader,
    test_loader=test_loader,
    model=conditional_transformer,
    optimizer=optimizer,
    device=device,
    lr_scheduler=lr_scheduler,
)

# %%
trainer.train()
# Out:
# Epoch 1/50
# -------------------------------
# Batch 16/139, Loss: 3.4886, Accuracy: 0.2693
# Batch 32/139, Loss: 2.6468, Accuracy: 0.3180
# Batch 48/139, Loss: 2.6553, Accuracy: 0.3294
# Batch 64/139, Loss: 2.1971, Accuracy: 0.3772
# Batch 80/139, Loss: 2.2649, Accuracy: 0.3690
# Batch 96/139, Loss: 2.3381, Accuracy: 0.3656
# Batch 112/139, Loss: 2.1307, Accuracy: 0.3821
# Batch 128/139, Loss: 2.3455, Accuracy: 0.3882
# Test Loss: 2.2922,  Accuracy: 0.3963
# Epoch 2/50
# -------------------------------
# Batch 16/139, Loss: 2.2097, Accuracy: 0.3773
# Batch 32/139, Loss: 1.9747, Accuracy: 0.3957
# Batch 48/139, Loss: 2.0762, Accuracy: 0.3989
# Batch 64/139, Loss: 2.0523, Accuracy: 0.4008
# Batch 80/139, Loss: 1.9931, Accuracy: 0.4095
# Batch 96/139, Loss: 2.0568, Accuracy: 0.3975
# Batch 112/139, Loss: 1.8603, Accuracy: 0.4074
# Batch 128/139, Loss: 1.8830, Accuracy: 0.4028
# Test Loss: 1.8874,  Accuracy: 0.4491
# Epoch 3/50
# -------------------------------
# Batch 16/139, Loss: 1.9222, Accuracy: 0.4337
# Batch 32/139, Loss: 2.0244, Accuracy: 0.3824
# Batch 48/139, Loss: 1.8430, Accuracy: 0.4304
# Batch 64/139, Loss: 1.9641, Accuracy: 0.4185
# Batch 80/139, Loss: 1.8495, Accuracy: 0.4217
# Batch 96/139, Loss: 1.8757, Accuracy: 0.4068
# Batch 112/139, Loss: 1.7247, Accuracy: 0.4201
# Batch 128/139, Loss: 1.8306, Accuracy: 0.4328
# Test Loss: 1.7716,  Accuracy: 0.4327
# Epoch 4/50
# -------------------------------
# Batch 16/139, Loss: 1.6828, Accuracy: 0.4401
# Batch 32/139, Loss: 1.8722, Accuracy: 0.4182
# Batch 48/139, Loss: 1.9179, Accuracy: 0.3917
# Batch 64/139, Loss: 1.7588, Accuracy: 0.4383
# Batch 80/139, Loss: 1.7946, Accuracy: 0.4364
# Batch 96/139, Loss: 1.7936, Accuracy: 0.4306
# Batch 112/139, Loss: 1.8061, Accuracy: 0.4322
# Batch 128/139, Loss: 1.8270, Accuracy: 0.4532
# Test Loss: 1.8385,  Accuracy: 0.4352
# Epoch 5/50
# -------------------------------
# Batch 16/139, Loss: 1.8596, Accuracy: 0.4387
# Batch 32/139, Loss: 1.7503, Accuracy: 0.4266
# Batch 48/139, Loss: 1.7327, Accuracy: 0.4461
# Batch 64/139, Loss: 1.7462, Accuracy: 0.4547
# Batch 80/139, Loss: 1.6689, Accuracy: 0.4774
# Batch 96/139, Loss: 1.7599, Accuracy: 0.4253
# Batch 112/139, Loss: 1.8731, Accuracy: 0.4367
# Batch 128/139, Loss: 1.7001, Accuracy: 0.4316
# Test Loss: 1.8127,  Accuracy: 0.4413
# Epoch 6/50
# -------------------------------
# Batch 16/139, Loss: 1.7931, Accuracy: 0.4299
# Batch 32/139, Loss: 1.7223, Accuracy: 0.4640
# Batch 48/139, Loss: 1.7261, Accuracy: 0.4603
# Batch 64/139, Loss: 1.7017, Accuracy: 0.4578
# Batch 80/139, Loss: 1.6918, Accuracy: 0.4584
# Batch 96/139, Loss: 1.6440, Accuracy: 0.4916
# Batch 112/139, Loss: 1.7381, Accuracy: 0.4567
# Batch 128/139, Loss: 1.7710, Accuracy: 0.4297
# Test Loss: 1.6353,  Accuracy: 0.4934
# Epoch 7/50
# -------------------------------
# Batch 16/139, Loss: 1.7458, Accuracy: 0.4480
# Batch 32/139, Loss: 1.6596, Accuracy: 0.4623
# Batch 48/139, Loss: 1.6544, Accuracy: 0.4648
# Batch 64/139, Loss: 1.7931, Accuracy: 0.4465
# Batch 80/139, Loss: 1.7520, Accuracy: 0.4717
# Batch 96/139, Loss: 1.6975, Accuracy: 0.4799
# Batch 112/139, Loss: 1.8171, Accuracy: 0.4484
# Batch 128/139, Loss: 1.7057, Accuracy: 0.4562
# Test Loss: 1.6914,  Accuracy: 0.4746
# Epoch 8/50
# -------------------------------
# Batch 16/139, Loss: 1.7976, Accuracy: 0.4513
# Batch 32/139, Loss: 1.5960, Accuracy: 0.4944
# Batch 48/139, Loss: 1.7194, Accuracy: 0.4649
# Batch 64/139, Loss: 1.5952, Accuracy: 0.4964
# Batch 80/139, Loss: 1.8156, Accuracy: 0.4497
# Batch 96/139, Loss: 1.6950, Accuracy: 0.4693
# Batch 112/139, Loss: 1.7575, Accuracy: 0.4454
# Batch 128/139, Loss: 1.8041, Accuracy: 0.4664
# Test Loss: 1.6943,  Accuracy: 0.4820
# Epoch 9/50
# -------------------------------
# Batch 16/139, Loss: 1.7346, Accuracy: 0.4861
# Batch 32/139, Loss: 1.6688, Accuracy: 0.4925
# Batch 48/139, Loss: 1.6731, Accuracy: 0.4840
# Batch 64/139, Loss: 1.6585, Accuracy: 0.5107
# Batch 80/139, Loss: 1.6344, Accuracy: 0.5073
# Batch 96/139, Loss: 1.7190, Accuracy: 0.5077
# Batch 112/139, Loss: 1.5940, Accuracy: 0.5271
# Batch 128/139, Loss: 1.6488, Accuracy: 0.5167
# Test Loss: 1.5600,  Accuracy: 0.5357
# Epoch 10/50
# -------------------------------
# Batch 16/139, Loss: 1.5781, Accuracy: 0.5347
# Batch 32/139, Loss: 1.4858, Accuracy: 0.5384
# Batch 48/139, Loss: 1.6170, Accuracy: 0.5487
# Batch 64/139, Loss: 1.6389, Accuracy: 0.5073
# Batch 80/139, Loss: 1.7040, Accuracy: 0.5205
# Batch 96/139, Loss: 1.6228, Accuracy: 0.5317
# Batch 112/139, Loss: 1.5421, Accuracy: 0.5555
# Batch 128/139, Loss: 1.3898, Accuracy: 0.5682
# Test Loss: 1.5406,  Accuracy: 0.5608
# Epoch 11/50
# -------------------------------
# Batch 16/139, Loss: 1.4917, Accuracy: 0.5673
# Batch 32/139, Loss: 1.6358, Accuracy: 0.5430
# Batch 48/139, Loss: 1.4869, Accuracy: 0.5665
# Batch 64/139, Loss: 1.4319, Accuracy: 0.5880
# Batch 80/139, Loss: 1.5452, Accuracy: 0.5358
# Batch 96/139, Loss: 1.4703, Accuracy: 0.5786
# Batch 112/139, Loss: 1.6750, Accuracy: 0.5381
# Batch 128/139, Loss: 1.4755, Accuracy: 0.5734
# Test Loss: 1.5307,  Accuracy: 0.5446
# Epoch 12/50
# -------------------------------
# Batch 16/139, Loss: 1.4991, Accuracy: 0.5652
# Batch 32/139, Loss: 1.5828, Accuracy: 0.5518
# Batch 48/139, Loss: 1.5353, Accuracy: 0.5621
# Batch 64/139, Loss: 1.3674, Accuracy: 0.6076
# Batch 80/139, Loss: 1.3165, Accuracy: 0.6198
# Batch 96/139, Loss: 1.4510, Accuracy: 0.5894
# Batch 112/139, Loss: 1.3744, Accuracy: 0.5997
# Batch 128/139, Loss: 1.5174, Accuracy: 0.5731
# Test Loss: 1.5570,  Accuracy: 0.5570
# Epoch 13/50
# -------------------------------
# Batch 16/139, Loss: 1.4449, Accuracy: 0.5808
# Batch 32/139, Loss: 1.5115, Accuracy: 0.5583
# Batch 48/139, Loss: 1.6380, Accuracy: 0.5573
# Batch 64/139, Loss: 1.4335, Accuracy: 0.5721
# Batch 80/139, Loss: 1.5137, Accuracy: 0.5803
# Batch 96/139, Loss: 1.5533, Accuracy: 0.5459
# Batch 112/139, Loss: 1.6807, Accuracy: 0.5368
# Batch 128/139, Loss: 1.3635, Accuracy: 0.6033
# Test Loss: 1.5146,  Accuracy: 0.5717
# Epoch 14/50
# -------------------------------
# Batch 16/139, Loss: 1.4800, Accuracy: 0.5950
# Batch 32/139, Loss: 1.3922, Accuracy: 0.5884
# Batch 48/139, Loss: 1.3386, Accuracy: 0.6072
# Batch 64/139, Loss: 1.5816, Accuracy: 0.5531
# Batch 80/139, Loss: 1.5098, Accuracy: 0.5711
# Batch 96/139, Loss: 1.5981, Accuracy: 0.5553
# Batch 112/139, Loss: 1.5693, Accuracy: 0.5713
# Batch 128/139, Loss: 1.4047, Accuracy: 0.5962
# Test Loss: 1.5515,  Accuracy: 0.5542
# Epoch 15/50
# -------------------------------
# Batch 16/139, Loss: 1.5268, Accuracy: 0.5600
# Batch 32/139, Loss: 1.4103, Accuracy: 0.5897
# Batch 48/139, Loss: 1.4007, Accuracy: 0.5896
# Batch 64/139, Loss: 1.5732, Accuracy: 0.5597
# Batch 80/139, Loss: 1.5166, Accuracy: 0.5776
# Batch 96/139, Loss: 1.2991, Accuracy: 0.6210
# Batch 112/139, Loss: 1.4008, Accuracy: 0.5906
# Batch 128/139, Loss: 1.4214, Accuracy: 0.5915
# Test Loss: 1.5782,  Accuracy: 0.5868
# Epoch 16/50
# -------------------------------
# Batch 16/139, Loss: 1.5499, Accuracy: 0.5761
# Batch 32/139, Loss: 1.5275, Accuracy: 0.5682
# Batch 48/139, Loss: 1.3995, Accuracy: 0.5910
# Batch 64/139, Loss: 1.3590, Accuracy: 0.5998
# Batch 80/139, Loss: 1.5215, Accuracy: 0.5686
# Batch 96/139, Loss: 1.4804, Accuracy: 0.5848
# Batch 112/139, Loss: 1.6343, Accuracy: 0.5356
# Batch 128/139, Loss: 1.4577, Accuracy: 0.5982
# Test Loss: 1.5865,  Accuracy: 0.5555
# Epoch 17/50
# -------------------------------
# Batch 16/139, Loss: 1.5319, Accuracy: 0.5726
# Batch 32/139, Loss: 1.4333, Accuracy: 0.5881
# Batch 48/139, Loss: 1.5813, Accuracy: 0.5649
# Batch 64/139, Loss: 1.4747, Accuracy: 0.5850
# Batch 80/139, Loss: 1.3499, Accuracy: 0.6335
# Batch 96/139, Loss: 1.4052, Accuracy: 0.6095
# Batch 112/139, Loss: 1.2956, Accuracy: 0.6336
# Batch 128/139, Loss: 1.3202, Accuracy: 0.6169
# Test Loss: 1.3828,  Accuracy: 0.6082
# Epoch 18/50
# -------------------------------
# Batch 16/139, Loss: 1.4501, Accuracy: 0.5947
# Batch 32/139, Loss: 1.3684, Accuracy: 0.6184
# Batch 48/139, Loss: 1.3801, Accuracy: 0.5918
# Batch 64/139, Loss: 1.4205, Accuracy: 0.5974
# Batch 80/139, Loss: 1.4436, Accuracy: 0.5912
# Batch 96/139, Loss: 1.4489, Accuracy: 0.5878
# Batch 112/139, Loss: 1.5876, Accuracy: 0.5584
# Batch 128/139, Loss: 1.3820, Accuracy: 0.5948
# Test Loss: 1.3770,  Accuracy: 0.6142
# Epoch 19/50
# -------------------------------
# Batch 16/139, Loss: 1.2939, Accuracy: 0.6416
# Batch 32/139, Loss: 1.5555, Accuracy: 0.5810
# Batch 48/139, Loss: 1.4354, Accuracy: 0.5834
# Batch 64/139, Loss: 1.3913, Accuracy: 0.5882
# Batch 80/139, Loss: 1.4392, Accuracy: 0.5874
# Batch 96/139, Loss: 1.4817, Accuracy: 0.5959
# Batch 112/139, Loss: 1.4065, Accuracy: 0.5927
# Batch 128/139, Loss: 1.2627, Accuracy: 0.6401
# Test Loss: 1.3985,  Accuracy: 0.6062
# Epoch 20/50
# -------------------------------
# Batch 16/139, Loss: 1.5490, Accuracy: 0.5730
# Batch 32/139, Loss: 1.4419, Accuracy: 0.5883
# Batch 48/139, Loss: 1.4999, Accuracy: 0.5702
# Batch 64/139, Loss: 1.2218, Accuracy: 0.6438
# Batch 80/139, Loss: 1.4588, Accuracy: 0.5946
# Batch 96/139, Loss: 1.4024, Accuracy: 0.6088
# Batch 112/139, Loss: 1.3491, Accuracy: 0.6142
# Batch 128/139, Loss: 1.3709, Accuracy: 0.6004
# Test Loss: 1.3058,  Accuracy: 0.6257
# Epoch 21/50
# -------------------------------
# Batch 16/139, Loss: 1.6263, Accuracy: 0.5521
# Batch 32/139, Loss: 1.4136, Accuracy: 0.5976
# Batch 48/139, Loss: 1.4512, Accuracy: 0.5946
# Batch 64/139, Loss: 1.3908, Accuracy: 0.6034
# Batch 80/139, Loss: 1.4439, Accuracy: 0.5994
# Batch 96/139, Loss: 1.4246, Accuracy: 0.5987
# Batch 112/139, Loss: 1.4765, Accuracy: 0.5932
# Batch 128/139, Loss: 1.3663, Accuracy: 0.6126
# Test Loss: 1.3022,  Accuracy: 0.6188
# Epoch 22/50
# -------------------------------
# Batch 16/139, Loss: 1.4683, Accuracy: 0.6021
# Batch 32/139, Loss: 1.3061, Accuracy: 0.6250
# Batch 48/139, Loss: 1.4166, Accuracy: 0.6062
# Batch 64/139, Loss: 1.3828, Accuracy: 0.6091
# Batch 80/139, Loss: 1.4481, Accuracy: 0.5906
# Batch 96/139, Loss: 1.4174, Accuracy: 0.6105
# Batch 112/139, Loss: 1.3397, Accuracy: 0.6136
# Batch 128/139, Loss: 1.3115, Accuracy: 0.6178
# Test Loss: 1.3384,  Accuracy: 0.6202
# Epoch 23/50
# -------------------------------
# Batch 16/139, Loss: 1.5119, Accuracy: 0.5731
# Batch 32/139, Loss: 1.3826, Accuracy: 0.5867
# Batch 48/139, Loss: 1.3792, Accuracy: 0.6119
# Batch 64/139, Loss: 1.3251, Accuracy: 0.6167
# Batch 80/139, Loss: 1.3239, Accuracy: 0.6228
# Batch 96/139, Loss: 1.4058, Accuracy: 0.6069
# Batch 112/139, Loss: 1.3941, Accuracy: 0.5964
# Batch 128/139, Loss: 1.4371, Accuracy: 0.6021
# Test Loss: 1.4392,  Accuracy: 0.5877
# Epoch 24/50
# -------------------------------
# Batch 16/139, Loss: 1.2762, Accuracy: 0.6386
# Batch 32/139, Loss: 1.3251, Accuracy: 0.6195
# Batch 48/139, Loss: 1.3457, Accuracy: 0.6105
# Batch 64/139, Loss: 1.3725, Accuracy: 0.6256
# Batch 80/139, Loss: 1.2938, Accuracy: 0.6269
# Batch 96/139, Loss: 1.5489, Accuracy: 0.5796
# Batch 112/139, Loss: 1.2853, Accuracy: 0.6389
# Batch 128/139, Loss: 1.4988, Accuracy: 0.5932
# Test Loss: 1.3437,  Accuracy: 0.6093
# Epoch 25/50
# -------------------------------
# Batch 16/139, Loss: 1.4054, Accuracy: 0.5935
# Batch 32/139, Loss: 1.3049, Accuracy: 0.6342
# Batch 48/139, Loss: 1.5541, Accuracy: 0.5794
# Batch 64/139, Loss: 1.3710, Accuracy: 0.6068
# Batch 80/139, Loss: 1.4590, Accuracy: 0.5781
# Batch 96/139, Loss: 1.4595, Accuracy: 0.5931
# Batch 112/139, Loss: 1.2720, Accuracy: 0.6269
# Batch 128/139, Loss: 1.3417, Accuracy: 0.6192
# Test Loss: 1.2616,  Accuracy: 0.6386
# Epoch 26/50
# -------------------------------
# Batch 16/139, Loss: 1.5496, Accuracy: 0.5810
# Batch 32/139, Loss: 1.2987, Accuracy: 0.6269
# Batch 48/139, Loss: 1.3163, Accuracy: 0.6276
# Batch 64/139, Loss: 1.3255, Accuracy: 0.6270
# Batch 80/139, Loss: 1.3085, Accuracy: 0.6374
# Batch 96/139, Loss: 1.2870, Accuracy: 0.6332
# Batch 112/139, Loss: 1.4712, Accuracy: 0.5825
# Batch 128/139, Loss: 1.3825, Accuracy: 0.6066
# Test Loss: 1.2355,  Accuracy: 0.6391
# Epoch 27/50
# -------------------------------
# Batch 16/139, Loss: 1.4434, Accuracy: 0.6022
# Batch 32/139, Loss: 1.4159, Accuracy: 0.6071
# Batch 48/139, Loss: 1.3219, Accuracy: 0.6170
# Batch 64/139, Loss: 1.5441, Accuracy: 0.5881
# Batch 80/139, Loss: 1.3719, Accuracy: 0.6124
# Batch 96/139, Loss: 1.3400, Accuracy: 0.6185
# Batch 112/139, Loss: 1.4141, Accuracy: 0.5926
# Batch 128/139, Loss: 1.3728, Accuracy: 0.6217
# Test Loss: 1.4541,  Accuracy: 0.6026
# Epoch 28/50
# -------------------------------
# Batch 16/139, Loss: 1.2250, Accuracy: 0.6518
# Batch 32/139, Loss: 1.3518, Accuracy: 0.6212
# Batch 48/139, Loss: 1.5177, Accuracy: 0.5761
# Batch 64/139, Loss: 1.3601, Accuracy: 0.6349
# Batch 80/139, Loss: 1.3603, Accuracy: 0.6134
# Batch 96/139, Loss: 1.4355, Accuracy: 0.5873
# Batch 112/139, Loss: 1.4099, Accuracy: 0.6013
# Batch 128/139, Loss: 1.3265, Accuracy: 0.6244
# Test Loss: 1.3494,  Accuracy: 0.6346
# Epoch 29/50
# -------------------------------
# Batch 16/139, Loss: 1.4605, Accuracy: 0.5998
# Batch 32/139, Loss: 1.1842, Accuracy: 0.6633
# Batch 48/139, Loss: 1.3316, Accuracy: 0.6209
# Batch 64/139, Loss: 1.3920, Accuracy: 0.6142
# Batch 80/139, Loss: 1.4882, Accuracy: 0.5748
# Batch 96/139, Loss: 1.3227, Accuracy: 0.6165
# Batch 112/139, Loss: 1.4158, Accuracy: 0.6078
# Batch 128/139, Loss: 1.2995, Accuracy: 0.6386
# Test Loss: 1.2256,  Accuracy: 0.6503
# Epoch 30/50
# -------------------------------
# Batch 16/139, Loss: 1.5226, Accuracy: 0.5813
# Batch 32/139, Loss: 1.4205, Accuracy: 0.6100
# Batch 48/139, Loss: 1.4223, Accuracy: 0.5993
# Batch 64/139, Loss: 1.3750, Accuracy: 0.5985
# Batch 80/139, Loss: 1.2527, Accuracy: 0.6542
# Batch 96/139, Loss: 1.3516, Accuracy: 0.6271
# Batch 112/139, Loss: 1.3764, Accuracy: 0.6249
# Batch 128/139, Loss: 1.4084, Accuracy: 0.6071
# Test Loss: 1.2974,  Accuracy: 0.6430
# Epoch 31/50
# -------------------------------
# Batch 16/139, Loss: 1.3459, Accuracy: 0.6070
# Batch 32/139, Loss: 1.2841, Accuracy: 0.6446
# Batch 48/139, Loss: 1.3438, Accuracy: 0.6230
# Batch 64/139, Loss: 1.2938, Accuracy: 0.6459
# Batch 80/139, Loss: 1.3608, Accuracy: 0.6153
# Batch 96/139, Loss: 1.3684, Accuracy: 0.6070
# Batch 112/139, Loss: 1.2904, Accuracy: 0.6407
# Batch 128/139, Loss: 1.2826, Accuracy: 0.6336
# Test Loss: 1.2630,  Accuracy: 0.6470
# Epoch 32/50
# -------------------------------
# Batch 16/139, Loss: 1.2671, Accuracy: 0.6232
# Batch 32/139, Loss: 1.3636, Accuracy: 0.6262
# Batch 48/139, Loss: 1.3396, Accuracy: 0.6215
# Batch 64/139, Loss: 1.2546, Accuracy: 0.6430
# Batch 80/139, Loss: 1.4229, Accuracy: 0.6203
# Batch 96/139, Loss: 1.3814, Accuracy: 0.6142
# Batch 112/139, Loss: 1.4184, Accuracy: 0.6177
# Batch 128/139, Loss: 1.3551, Accuracy: 0.6282
# Test Loss: 1.3906,  Accuracy: 0.6089
# Epoch 33/50
# -------------------------------
# Batch 16/139, Loss: 1.3162, Accuracy: 0.6277
# Batch 32/139, Loss: 1.2844, Accuracy: 0.6345
# Batch 48/139, Loss: 1.2509, Accuracy: 0.6417
# Batch 64/139, Loss: 1.3795, Accuracy: 0.6063
# Batch 80/139, Loss: 1.3291, Accuracy: 0.6167
# Batch 96/139, Loss: 1.4956, Accuracy: 0.5920
# Batch 112/139, Loss: 1.3460, Accuracy: 0.6337
# Batch 128/139, Loss: 1.3402, Accuracy: 0.6291
# Test Loss: 1.2877,  Accuracy: 0.6313
# Epoch 34/50
# -------------------------------
# Batch 16/139, Loss: 1.4142, Accuracy: 0.6150
# Batch 32/139, Loss: 1.3937, Accuracy: 0.6133
# Batch 48/139, Loss: 1.1947, Accuracy: 0.6607
# Batch 64/139, Loss: 1.4653, Accuracy: 0.5963
# Batch 80/139, Loss: 1.2505, Accuracy: 0.6354
# Batch 96/139, Loss: 1.4689, Accuracy: 0.5947
# Batch 112/139, Loss: 1.2443, Accuracy: 0.6517
# Batch 128/139, Loss: 1.2782, Accuracy: 0.6418
# Test Loss: 1.2799,  Accuracy: 0.6243
# Epoch 35/50
# -------------------------------
# Batch 16/139, Loss: 1.3408, Accuracy: 0.6153
# Batch 32/139, Loss: 1.2861, Accuracy: 0.6498
# Batch 48/139, Loss: 1.3567, Accuracy: 0.6274
# Batch 64/139, Loss: 1.3487, Accuracy: 0.6151
# Batch 80/139, Loss: 1.4686, Accuracy: 0.5982
# Batch 96/139, Loss: 1.3731, Accuracy: 0.6090
# Batch 112/139, Loss: 1.3028, Accuracy: 0.6254
# Batch 128/139, Loss: 1.3164, Accuracy: 0.6392
# Test Loss: 1.2218,  Accuracy: 0.6673
# Epoch 36/50
# -------------------------------
# Batch 16/139, Loss: 1.2161, Accuracy: 0.6521
# Batch 32/139, Loss: 1.3722, Accuracy: 0.6084
# Batch 48/139, Loss: 1.3438, Accuracy: 0.6336
# Batch 64/139, Loss: 1.3687, Accuracy: 0.6173
# Batch 80/139, Loss: 1.3589, Accuracy: 0.6380
# Batch 96/139, Loss: 1.2428, Accuracy: 0.6506
# Batch 112/139, Loss: 1.3433, Accuracy: 0.6229
# Batch 128/139, Loss: 1.4611, Accuracy: 0.5987
# Test Loss: 1.2465,  Accuracy: 0.6363
# Epoch 37/50
# -------------------------------
# Batch 16/139, Loss: 1.3198, Accuracy: 0.6303
# Batch 32/139, Loss: 1.4070, Accuracy: 0.6076
# Batch 48/139, Loss: 1.2302, Accuracy: 0.6408
# Batch 64/139, Loss: 1.4553, Accuracy: 0.6004
# Batch 80/139, Loss: 1.3135, Accuracy: 0.6294
# Batch 96/139, Loss: 1.3510, Accuracy: 0.6235
# Batch 112/139, Loss: 1.4473, Accuracy: 0.6115
# Batch 128/139, Loss: 1.3009, Accuracy: 0.6378
# Test Loss: 1.2106,  Accuracy: 0.6589
# Epoch 38/50
# -------------------------------
# Batch 16/139, Loss: 1.3742, Accuracy: 0.6081
# Batch 32/139, Loss: 1.2792, Accuracy: 0.6293
# Batch 48/139, Loss: 1.2600, Accuracy: 0.6485
# Batch 64/139, Loss: 1.2604, Accuracy: 0.6519
# Batch 80/139, Loss: 1.3222, Accuracy: 0.6244
# Batch 96/139, Loss: 1.4547, Accuracy: 0.5963
# Batch 112/139, Loss: 1.3194, Accuracy: 0.6275
# Batch 128/139, Loss: 1.4619, Accuracy: 0.6082
# Test Loss: 1.1420,  Accuracy: 0.6744
# Epoch 39/50
# -------------------------------
# Batch 16/139, Loss: 1.2806, Accuracy: 0.6402
# Batch 32/139, Loss: 1.3384, Accuracy: 0.6155
# Batch 48/139, Loss: 1.2798, Accuracy: 0.6388
# Batch 64/139, Loss: 1.3470, Accuracy: 0.6282
# Batch 80/139, Loss: 1.2781, Accuracy: 0.6317
# Batch 96/139, Loss: 1.4421, Accuracy: 0.6051
# Batch 112/139, Loss: 1.3580, Accuracy: 0.6203
# Batch 128/139, Loss: 1.2453, Accuracy: 0.6477
# Test Loss: 1.3098,  Accuracy: 0.6345
# Epoch 40/50
# -------------------------------
# Batch 16/139, Loss: 1.3856, Accuracy: 0.6035
# Batch 32/139, Loss: 1.2770, Accuracy: 0.6462
# Batch 48/139, Loss: 1.3140, Accuracy: 0.6376
# Batch 64/139, Loss: 1.2265, Accuracy: 0.6545
# Batch 80/139, Loss: 1.2553, Accuracy: 0.6486
# Batch 96/139, Loss: 1.3605, Accuracy: 0.6179
# Batch 112/139, Loss: 1.1891, Accuracy: 0.6473
# Batch 128/139, Loss: 1.2689, Accuracy: 0.6530
# Test Loss: 1.3014,  Accuracy: 0.6383
# Epoch 41/50
# -------------------------------
# Batch 16/139, Loss: 1.3633, Accuracy: 0.6075
# Batch 32/139, Loss: 1.3186, Accuracy: 0.6225
# Batch 48/139, Loss: 1.3714, Accuracy: 0.6250
# Batch 64/139, Loss: 1.3051, Accuracy: 0.6397
# Batch 80/139, Loss: 1.4230, Accuracy: 0.5906
# Batch 96/139, Loss: 1.3672, Accuracy: 0.6216
# Batch 112/139, Loss: 1.3272, Accuracy: 0.6401
# Batch 128/139, Loss: 1.4724, Accuracy: 0.5955
# Test Loss: 1.2940,  Accuracy: 0.6491
# Epoch 42/50
# -------------------------------
# Batch 16/139, Loss: 1.2139, Accuracy: 0.6427
# Batch 32/139, Loss: 1.2693, Accuracy: 0.6436
# Batch 48/139, Loss: 1.2934, Accuracy: 0.6354
# Batch 64/139, Loss: 1.3508, Accuracy: 0.6199
# Batch 80/139, Loss: 1.3768, Accuracy: 0.6238
# Batch 96/139, Loss: 1.3035, Accuracy: 0.6409
# Batch 112/139, Loss: 1.3089, Accuracy: 0.6266
# Batch 128/139, Loss: 1.4693, Accuracy: 0.6015
# Test Loss: 1.3379,  Accuracy: 0.6366
# Epoch 43/50
# -------------------------------
# Batch 16/139, Loss: 1.5179, Accuracy: 0.5918
# Batch 32/139, Loss: 1.3849, Accuracy: 0.6038
# Batch 48/139, Loss: 1.3597, Accuracy: 0.6344
# Batch 64/139, Loss: 1.3148, Accuracy: 0.6308
# Batch 80/139, Loss: 1.2320, Accuracy: 0.6517
# Batch 96/139, Loss: 1.3156, Accuracy: 0.6282
# Batch 112/139, Loss: 1.4767, Accuracy: 0.5911
# Batch 128/139, Loss: 1.2689, Accuracy: 0.6470
# Test Loss: 1.2041,  Accuracy: 0.6608
# Epoch 44/50
# -------------------------------
# Batch 16/139, Loss: 1.2973, Accuracy: 0.6329
# Batch 32/139, Loss: 1.3424, Accuracy: 0.6447
# Batch 48/139, Loss: 1.2299, Accuracy: 0.6448
# Batch 64/139, Loss: 1.3986, Accuracy: 0.6199
# Batch 80/139, Loss: 1.3402, Accuracy: 0.6354
# Batch 96/139, Loss: 1.2945, Accuracy: 0.6438
# Batch 112/139, Loss: 1.3211, Accuracy: 0.6273
# Batch 128/139, Loss: 1.1699, Accuracy: 0.6609
# Test Loss: 1.2494,  Accuracy: 0.6328
# Epoch 45/50
# -------------------------------
# Batch 16/139, Loss: 1.3379, Accuracy: 0.6324
# Batch 32/139, Loss: 1.2231, Accuracy: 0.6552
# Batch 48/139, Loss: 1.3329, Accuracy: 0.6176
# Batch 64/139, Loss: 1.3245, Accuracy: 0.6353
# Batch 80/139, Loss: 1.4512, Accuracy: 0.5955
# Batch 96/139, Loss: 1.3038, Accuracy: 0.6279
# Batch 112/139, Loss: 1.2698, Accuracy: 0.6362
# Batch 128/139, Loss: 1.3289, Accuracy: 0.6344
# Test Loss: 1.2034,  Accuracy: 0.6503
# Epoch 46/50
# -------------------------------
# Batch 16/139, Loss: 1.3711, Accuracy: 0.6214
# Batch 32/139, Loss: 1.3592, Accuracy: 0.6292
# Batch 48/139, Loss: 1.4014, Accuracy: 0.6060
# Batch 64/139, Loss: 1.2474, Accuracy: 0.6346
# Batch 80/139, Loss: 1.2626, Accuracy: 0.6375
# Batch 96/139, Loss: 1.4186, Accuracy: 0.5963
# Batch 112/139, Loss: 1.3214, Accuracy: 0.6328
# Batch 128/139, Loss: 1.3145, Accuracy: 0.6209
# Test Loss: 1.3172,  Accuracy: 0.6247
# Epoch 47/50
# -------------------------------
# Batch 16/139, Loss: 1.2527, Accuracy: 0.6437
# Batch 32/139, Loss: 1.4613, Accuracy: 0.5965
# Batch 48/139, Loss: 1.3491, Accuracy: 0.6290
# Batch 64/139, Loss: 1.3204, Accuracy: 0.6358
# Batch 80/139, Loss: 1.1808, Accuracy: 0.6686
# Batch 96/139, Loss: 1.1338, Accuracy: 0.6787
# Batch 112/139, Loss: 1.2678, Accuracy: 0.6303
# Batch 128/139, Loss: 1.4298, Accuracy: 0.6038
# Test Loss: 1.1923,  Accuracy: 0.6715
# Epoch 48/50
# -------------------------------
# Batch 16/139, Loss: 1.4905, Accuracy: 0.5999
# Batch 32/139, Loss: 1.3731, Accuracy: 0.6263
# Batch 48/139, Loss: 1.2247, Accuracy: 0.6621
# Batch 64/139, Loss: 1.5500, Accuracy: 0.5742
# Batch 80/139, Loss: 1.2680, Accuracy: 0.6507
# Batch 96/139, Loss: 1.3988, Accuracy: 0.5994
# Batch 112/139, Loss: 1.3361, Accuracy: 0.6318
# Batch 128/139, Loss: 1.3635, Accuracy: 0.6209
# Test Loss: 1.3100,  Accuracy: 0.6339
# Epoch 49/50
# -------------------------------
# Batch 16/139, Loss: 1.3197, Accuracy: 0.6363
# Batch 32/139, Loss: 1.2662, Accuracy: 0.6507
# Batch 48/139, Loss: 1.3310, Accuracy: 0.6327
# Batch 64/139, Loss: 1.2677, Accuracy: 0.6408
# Batch 80/139, Loss: 1.2460, Accuracy: 0.6318
# Batch 96/139, Loss: 1.3155, Accuracy: 0.6352
# Batch 112/139, Loss: 1.2113, Accuracy: 0.6502
# Batch 128/139, Loss: 1.3549, Accuracy: 0.6306
# Test Loss: 1.2744,  Accuracy: 0.6279
# Epoch 50/50
# -------------------------------
# Batch 16/139, Loss: 1.3264, Accuracy: 0.6294
# Batch 32/139, Loss: 1.3450, Accuracy: 0.6215
# Batch 48/139, Loss: 1.5127, Accuracy: 0.6040
# Batch 64/139, Loss: 1.3260, Accuracy: 0.6282
# Batch 80/139, Loss: 1.1843, Accuracy: 0.6641
# Batch 96/139, Loss: 1.3346, Accuracy: 0.6309
# Batch 112/139, Loss: 1.5036, Accuracy: 0.5875
# Batch 128/139, Loss: 1.3845, Accuracy: 0.6247
# Test Loss: 1.2853,  Accuracy: 0.6379

# %%
# Save the model
torch.save(conditional_transformer.state_dict(), "../Models/ConditionalTransformerS.pt")

# %% [markdown]
# ## Inference

# %%
from src import *

parser = chord_parser.Main()
interpreter = seq_interpreter.Main(parser)

# %%
def pad(chords):
    """Pad the input 2D tensor [n] into shape [256] with zeros without the end of sequence token"""
    out = torch.zeros((256))
    out[0] = VOCAB_SIZE - 2 # Start of sequence token
    out[1:len(chords) + 1] = chords
    return out

# %%
dataset.all_genres, dataset.all_decades
# Out:
# (array(['Rock', 'Folk', 'Pop', 'Soundtrack', 'R&B, Funk & Soul', 'Country',
#         'Jazz', 'Experimental', 'Religious Music', 'Reggae & Ska',
#         'Hip Hop', 'Electronic', 'Comedy', 'Metal', 'Blues', 'World Music',
#         'Disco', 'Classical', 'New Age', 'Darkwave'], dtype=object),
#  array([1990, 2010, 1960, 1970, 2000, 1980, 2020, 1950], dtype=int64))

# %%
def generate_sequence(temperature, max_length, genres, decade):
    conditional_transformer.eval()
    with torch.inference_mode():
        x = torch.zeros((1, max_length + 1), dtype=torch.long, device=device)
        
        style = dataset.multi_hot(genres, decade).unsqueeze(0)
        for i in range(max_length):
            input_x = x[:, :i].squeeze(0)
            input_x = pad(input_x).long().unsqueeze(0)
            y_pred = conditional_transformer(input_x.to(device), style.to(device)).squeeze()[i]
            # Zero out the probability for the same as the previous chord
            if i > 0:
                y_pred[x[:, i - 1]] = -torch.inf
            # Sample from the distribution
            y_pred = F.softmax(y_pred, dim=0) ** (1 / temperature)
            x[:, i] = y_pred.multinomial(1).item()
            if x[:, i] == VOCAB_SIZE - 1:
                break

    return x[0, :-1]

# %%
seq = generate_sequence(1.0, 254, ["Jazz"], 1970)
print(interpreter.token_seq_to_chords(seq))
interpreter.play_seq(seq)
# Out:
# G# | D#sus4 | G# | C# | G# | Cm7 | G# | D#+9 | Fm7 | C#6 | EM9 | G# | C#6 | G# | C#6 | G# | C# | Fm7 | G#6/9 | G# | D#sus4 | Fm7 | C#6 | G# | C# | C#6 | G# | C#6 | G# | Fdim | G# | G#sus4 | G# | C#6 | G# | C# | C#/bI | D# | C#6 | A# | D# | Fm | Fm7 | A#7sus4 | C# | B6 | C#6 | G# | Gdim | Fm7 | C#6 | G# | Fm7 | G#6/9 | Edim7 | G# | G#/bI | Fm7 | C#6 | Fm7 | A#7sus4 | Fm7 | C#6 | G# | Fm7 | C#6 | G#
#                 <div id="midiPlayerDiv343"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv343");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>
